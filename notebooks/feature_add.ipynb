# %% [markdown]
# Certificate      101
# Meta_score       157
# Gross            169

# %% [markdown]
# # Enriquecendo o dataframe
#  - Puxando informações da API TMDB: Popularidade, detalhde de data, produtoras, palavras chaves e diversas outras variaveis que irão auxiliar na análise exploratória
#  - Criação de features financeiras robustas para AED
#  - Adição de certificados e datas de lançamentos manuais por meio de remap

# %%
import pandas as pd
import numpy as np

# %%
path = '../data/processed/pre_feature_eng.csv'
df = pd.read_csv(path)

# %%
df = df[['Series_Title', 'Released_Year']]
df.head()
# Out:
#                                     Series_Title  Released_Year
# 0                                  The Godfather           1972
# 1                                The Dark Knight           2008
# 2                         The Godfather: Part II           1974
# 3                                   12 Angry Men           1957
# 4  The Lord of the Rings: The Return of the King           2003

# %% [markdown]
# Adicionando ano de lançamento detalhado, palavras-chave e diminuindo o numero de valores nulos na coluna de certificados

# %%
import os
import requests
from dotenv import load_dotenv
import time
import numpy as np
load_dotenv()

API_KEY_TMDB = os.getenv("API_KEY_TMDB")

countrys = ["US", "GB", "CA", "FR", "JP", "DE", "ES", "IT", "BR"]

BASE_URL = "https://api.themoviedb.org/3"
HEADERS = {
    "accept": "application/json",
    "Authorization": f"Bearer {API_KEY_TMDB}"
}

# %%
def find_id(title: str, year: int, imdb_id=False):

    url = f"{BASE_URL}/search/movie"
    params = {
        "query": title,
        "year": year,
        "language": "en-US",
        "page": 1
    }
    
    try:
        response = requests.get(url, params=params, headers=HEADERS) 
        response.raise_for_status()
        
        data = response.json()
        results = data.get("results", [])
        
        if results:
            tmdb_id = results[0].get("id")
            
            if imdb_id:
                url = f"{BASE_URL}/movie/{tmdb_id}/external_ids"
                response = requests.get(url, headers=HEADERS)
                response.raise_for_status()
                return response.json().get("imdb_id")
            
            return tmdb_id
        else:
            return None
            
    except requests.RequestException as e:
        print(f"  -> Erro ao buscar ID no TMDB para '{title}': {e}")
        return None

# %% [markdown]
# Testando funcionamento da função de encontrar id (IMDB ou TMDB)

# %%
display(find_id("Fight Club", 1999))
display(find_id("Fight Club", 1999, imdb_id=True))
# Out:
# 550
# 'tt0137523'

# %%
from dateutil import parser


def get_release_certificate(movie_id: int):
    url = f"{BASE_URL}/movie/{movie_id}/release_dates"
    try:
        response = requests.get(url, headers=HEADERS)
        response.raise_for_status()
    except requests.RequestException as e:
        print(f"Erro na requisição para o filme ID {movie_id}: {e}")
        return None, None

    results = response.json().get("results", [])
    if not results:
        return None, None

    certification = None
    releases_by_country = {r["iso_3166_1"]: r["release_dates"] for r in results}

    for country in countrys:
        if country in releases_by_country:
            for release in releases_by_country[country]:
                cert = release.get("certification")
                if cert:
                    certification = cert
                    break
        if certification:
            break

    all_dates = [
        release["release_date"]
        for country_releases in releases_by_country.values()
        for release in country_releases
        if release.get("release_date")
    ]

    if all_dates:
        parsed_dates = [parser.parse(d) for d in all_dates]
        release_date = min(parsed_dates).strftime("%Y-%m-%d")
        return certification, release_date
    
    return certification, None

# %%
def get_keywords(id_movie):
    url = f"{BASE_URL}/movie/{id_movie}/keywords"

    try:
        response = requests.get(url, headers=HEADERS)
        response.raise_for_status()
        data = response.json()
    
        list_keywords = [i['name'] for i in data.get('keywords', [])]

    except requests.RequestException as e:
        print(f"Erro ao buscar keywords para o filme ID {id_movie}: {e}")
        return []

    return list_keywords

# %%
print(get_release_certificate(550))
print(get_keywords(550))
# Out:
# ('R', '1999-09-10')
# ['dual identity', 'rage and hate', 'based on novel or book', 'nihilism', 'fight', 'support group', 'dystopia', 'insomnia', 'alter ego', 'breaking the fourth wall', 'split personality', 'quitting a job', 'dissociative identity disorder', 'self destructiveness']

# %%
def fill_cer_date_keyw(df: pd.DataFrame, inicio=0) -> pd.DataFrame:
    df_copy = df.copy()
    df_copy['Keywords'] = None
    df_copy['date_details'] = None
    df_copy['Certificate'] = None
    for index in range(inicio, len(df_copy)):
        title = df_copy.loc[index, "Series_Title"]
        year = df_copy.loc[index, "Released_Year"]

        print(f"\nProcessando: '{title}' ({year})")
        
        
        try:
            movie_id = find_id(title, year)
        except Exception as e:
            print(f"Erro ao buscar ID para '{title}': {e}")
            continue

        if not movie_id:
            print(f"não encontrou id {title}")
            continue
        

        keywords = get_keywords(movie_id)
        df_copy.at[index, 'Keywords'] = keywords

        try:
            cert, date = get_release_certificate(movie_id)
        except Exception as e:
            print(f"Erro ao buscar informações de lançamento para '{title}': {e}")
            return df_copy, index

        if cert:
            df_copy.at[index, "Certificate"] = cert
            print(f"certificação atualizada: {cert}")

        if date:
            df_copy.at[index, "date_details"] = date
            print(f"data de lançamento atualizada: {date}")

    return df_copy

df = fill_cer_date_keyw(df, inicio=0)

# %%
missing_data_fill_dict = {
    "Soorarai Pottru": {
        "Keywords": "['biography', 'based on book', 'entrepreneur', 'low-cost airline']",
        "date_details": "2020-11-12",
        "Certificate": "U"
    },
    "Vikram Vedha": {
        "Keywords": "['neo-noir', 'gangster', 'police', 'vikramaditya', 'vedhalam']",
        "date_details": "2017-07-21",
        "Certificate": "U/A"
    },
    "Anand": {
        "Keywords": "['terminal illness', 'cancer', 'friendship', 'doctor', 'positive thinking']",
        "date_details": "1971-03-12",
        "Certificate": "U"
    },
    "Tumbbad": {
        "Keywords": "['horror', 'mythology', 'greed', 'treasure', 'monster']",
        "date_details": "2018-10-12",
        "Certificate": "A"
    },
    "Drishyam": {
        "Keywords": "['remake', 'murder', 'cover-up', 'family', 'police investigation']",
        "date_details": "2013-12-19",
        "Certificate": "U/A"
    },
    "Babam ve Oglum": {
        "Keywords": "['family drama', 'father son relationship', 'turkey', 'coup d\\'état']",
        "date_details": "2005-11-18",
        "Certificate": "NR"
    },
    "Uri: The Surgical Strike": {
        "Keywords": "['surgical strike', 'indian army', 'terrorism', 'based on true story']",
        "date_details": "2019-01-11",
        "Certificate": "U/A"
    },
    "Talvar": {
        "Keywords": "['murder investigation', 'based on true story', 'noida double murder case']",
        "date_details": "2015-10-02",
        "Certificate": "U/A"
    },
    "Queen": {
        "Keywords": "['self-discovery', 'honeymoon', 'travel', 'female protagonist', 'coming of age']",
        "date_details": "2014-03-07",
        "Certificate": "U/A"
    },
    "Paan Singh Tomar": {
        "Keywords": "['biography', 'athlete', 'dacoit', 'indian army', 'steeplechase']",
        "date_details": "2012-03-02",
        "Certificate": "U/A"
    },
    "Hera Pheri": {
        "Keywords": "['comedy', 'kidnapping', 'wrong number', 'mistaken identity']",
        "date_details": "2000-03-31",
        "Certificate": "U"
    },
    "Andaz Apna Apna": {
        "Keywords": "['comedy', 'mistaken identity', 'love triangle', 'kidnapping']",
        "date_details": "1994-04-11",
        "Certificate": "U"
    },
    "Yôjinbô": {
        "Keywords": "['samurai', 'ronin', 'feudal japan', 'jidaigeki', 'masterpiece']",
        "date_details": "1961-04-25",
        "Certificate": "NR"
    },
    "Pink": {
        "Keywords": "['courtroom drama', 'consent', 'women\\'s rights', 'false accusation']",
        "date_details": "2016-09-16",
        "Certificate": "U/A"
    },
    "OMG: Oh My God!": {
        "Keywords": "['satire', 'religion', 'god', 'lawsuit', 'earthquake', 'based on play']",
        "date_details": "2012-09-28",
        "Certificate": "U"
    },
    "Barfi!": {
        "Keywords": "['deaf-mute', 'autism', 'love triangle', 'comedy', 'drama']",
        "date_details": "2012-09-14",
        "Certificate": "U"
    },
    "Kahaani": {
        "Keywords": "['mystery', 'thriller', 'pregnant woman', 'kolkata', 'missing husband']",
        "date_details": "2012-03-09",
        "Certificate": "U/A"
    },
    "Zindagi Na Milegi Dobara": {
        "Keywords": "['road trip', 'friendship', 'spain', 'bachelor party', 'coming of age']",
        "date_details": "2011-07-15",
        "Certificate": "U/A"
    },
    "A Wednesday": {
        "Keywords": "['thriller', 'common man', 'terrorism', 'bomb threat', 'police']",
        "date_details": "2008-09-05",
        "Certificate": "U/A"
    },
    "Munna Bhai M.B.B.S.": {
        "Keywords": "['comedy', 'gangster', 'doctor', 'medical school', 'hospital']",
        "date_details": "2003-12-19",
        "Certificate": "U"
    },
    "Fa yeung nin wah": {
        "Keywords": "['romance', 'unconsummated love', 'hong kong', '1960s', 'neighbor']",
        "date_details": "2000-09-29",
        "Certificate": "PG"
    },
    "Badhaai ho": {
        "Keywords": "['social comedy', 'pregnancy', 'middle-aged parents', 'family']",
        "date_details": "2018-10-18",
        "Certificate": "U/A"
    },
    "Baby": {
        "Keywords": "['espionage', 'counter-terrorism', 'secret mission', 'indian intelligence']",
        "date_details": "2015-01-23",
        "Certificate": "U/A"
    },
    "Yip Man": {
        "Keywords": "['martial arts', 'biography', 'wing chun', 'sino-japanese war']",
        "date_details": "2008-12-12",
        "Certificate": "R"
    },
    "Nefes: Vatan Sagolsun": {
        "Keywords": "['war', 'turkish army', 'pkk', 'military outpost', 'turkey']",
        "date_details": "2009-10-16",
        "Certificate": "NR"
    },
    "Mar adentro": {
        "Keywords": "['euthanasia', 'quadriplegic', 'based on true story', 'spain']",
        "date_details": "2004-09-03",
        "Certificate": "PG-13"
    },
    "Kôkaku Kidôtai": {
        "Keywords": "['cyberpunk', 'anime', 'cyborg', 'artificial intelligence', 'philosophy']",
        "date_details": "1995-11-18",
        "Certificate": "NR"
    },
    "Out of the Past": {
        "Keywords": "['film noir', 'femme fatale', 'private eye', 'flashback', 'betrayal']",
        "date_details": "1947-11-25",
        "Certificate": "Approved"
    },
    "Arsenic and Old Lace": {
        "Keywords": "['black comedy', 'screwball comedy', 'murder', 'family', 'poison']",
        "date_details": "1944-09-23",
        "Certificate": "Approved"
    },
    "Raazi": {
        "Keywords": "['spy', 'thriller', 'based on true story', 'indo-pakistani war', 'patriotism']",
        "date_details": "2018-05-11",
        "Certificate": "U/A"
    },
    "M.S. Dhoni: The Untold Story": {
        "Keywords": "['biography', 'cricket', 'sports', 'indian cricket team']",
        "date_details": "2016-09-30",
        "Certificate": "U"
    },
    "Vicky Donor": {
        "Keywords": "['social comedy', 'sperm donor', 'infertility', 'delhi']",
        "date_details": "2012-04-20",
        "Certificate": "U/A"
    },
    "Once": {
        "Keywords": "['musical', 'romance', 'dublin', 'street musician', 'singer-songwriter']",
        "date_details": "2007-03-23",
        "Certificate": "R"
    },
    "Der Name der Rose": {
        "Keywords": "['mystery', 'middle ages', 'monastery', 'monk', 'based on novel']",
        "date_details": "1986-09-24",
        "Certificate": "R"
    },
    "Batoru rowaiaru": {
        "Keywords": "['dystopian', 'survival', 'high school students', 'island', 'cult film']",
        "date_details": "2000-12-16",
        "Certificate": "R15+"
    }
}

for i in df[df['Certificate'].isna() | df['date_details'].isna() | df['Keywords'].isna()].index:
    df.loc[i, 'Keywords'] = missing_data_fill_dict.get(df.loc[i, 'Series_Title'], {}).get('Keywords', np.nan)
    df.loc[i, 'date_details'] = missing_data_fill_dict.get(df.loc[i, 'Series_Title'], {}).get('date_details', np.nan)
    df.loc[i, 'Certificate'] = missing_data_fill_dict.get(df.loc[i, 'Series_Title'], {}).get('Certificate', np.nan)

# %%
df.isna().sum()
# Out:
# Series_Title     0
# Released_Year    0
# Keywords         0
# date_details     0
# Certificate      0
# dtype: int64

# %%
df.to_csv('../data/processed/check_2_processing.csv', index=False)

# %%
from dateutil import parser

def get_details_movie(title: str, year: int):
    search_url = f"{BASE_URL}/search/movie"
    params = {"query": title, "year": year, "language": "en-US", "page": 1}
    
    try:
        response = requests.get(search_url, params=params, headers=HEADERS)
        response.raise_for_status()
        data = response.json()
        results = data.get("results", [])

        if not results:
            return None

        tmdb_id = None
        for movie in results:
            if movie.get("title", "").lower() == title.lower():
                tmdb_id = movie.get("id")
                break
        
        if not tmdb_id:
            tmdb_id = results[0].get("id")

        if not tmdb_id:
            return None

        details_url = f"{BASE_URL}/movie/{tmdb_id}"
        details_params = {"append_to_response": "release_dates,keywords"}
        
        details_response = requests.get(details_url, params=details_params, headers=HEADERS)
        details_response.raise_for_status()
        details = details_response.json()

        certification = None
        release_date = None
        release_info = details.get("release_dates", {}).get("results", [])
        
        if release_info:
            releases_by_country = {r["iso_3166_1"]: r["release_dates"] for r in release_info}
            for country in countrys:
                if country in releases_by_country:
                    for release in releases_by_country[country]:
                        cert = release.get("certification")
                        if cert and cert.strip():
                            certification = cert
                            break
                if certification:
                    break
            
            all_dates = [
                release["release_date"]
                for country_releases in releases_by_country.values()
                for release in country_releases
                if release.get("release_date")
            ]
            if all_dates:
                parsed_dates = [parser.parse(d) for d in all_dates]
                if parsed_dates:
                    release_date = min(parsed_dates).strftime("%Y-%m-%d")

        return {
            "runtime": details.get("runtime"),
            "original_language": details.get("original_language"),
            "production_companies": [c["name"] for c in details.get("production_companies", [])],
            "production_countries": [c["name"] for c in details.get("production_countries", [])],
            "budget": details.get("budget"),
            "revenue": details.get("revenue"),
            "popularity": details.get("popularity"),
            "keywords": [k["name"] for k in details.get("keywords", {}).get("keywords", [])],
            "certificate": certification,
            "release_date": release_date
        }

    except requests.RequestException:
        return None

# %%
display(get_details_movie("Fight Club", 1999))
# Out:
# {'runtime': 139,
#  'original_language': 'en',
#  'production_companies': ['Fox 2000 Pictures',
#   'Regency Enterprises',
#   'Linson Entertainment',
#   '20th Century Fox',
#   'Taurus Film'],
#  'production_countries': ['Germany', 'United States of America'],
#  'budget': 63000000,
#  'revenue': 100853753,
#  'popularity': 25.5065,
#  'keywords': ['dual identity',
#   'rage and hate',
#   'based on novel or book',
#   'nihilism',
#   'fight',
#   'support group',
#   'dystopia',
#   'insomnia',
#   'alter ego',
#   'breaking the fourth wall',
#   'split personality',
#   'quitting a job',
#   'dissociative identity disorder',
#   'self destructiveness'],
#  'certificate': 'R',
#  'release_date': '1999-09-10'}

# %%
def enrich_row(row: pd.Series) -> pd.Series:
    title = row.get("Series_Title")
    year = row.get("Released_Year")

    print(f"\nProcessando: '{title}' ({year})")

    movie_data = get_details_movie(title, year)

    if movie_data:
        row['Budget'] = movie_data.get('budget')
        row['Revenue'] = movie_data.get('revenue')
        row['Popularity'] = movie_data.get('popularity')
        row['Original_Language'] = movie_data.get('original_language')
        row['Production_Companies'] = movie_data.get('production_companies')
        row['Production_Countries'] = movie_data.get('production_countries')

        if pd.isna(row.get('Gross')) and movie_data.get('revenue') is not None:
            row['Gross'] = movie_data['revenue']
            print(f"  -> Coluna 'Gross' preenchida com revenue: {movie_data['revenue']}")

    return row

def enrich_df(df: pd.DataFrame) -> pd.DataFrame:
    df_copy = df.copy()

    new_columns = [
        'Budget', 'Revenue', 'Popularity',
        'Original_Language', 'Production_Companies', 'Production_Countries'
    ]
    for col in new_columns:
        if col not in df_copy.columns:
            df_copy[col] = pd.NA

    df_copy = df_copy.apply(enrich_row, axis=1)

    print("\nProcesso de enriquecimento de dados concluído.")
    return df_copy

# %%
df = enrich_df(df)
df.to_csv('../data/processed/check_3_processing.csv', index=False)
# Out:
# Processando: 'The Godfather' (1972)
#   -> Coluna 'Gross' preenchida com revenue: 245066411
#
# Processando: 'The Dark Knight' (2008)
#   -> Coluna 'Gross' preenchida com revenue: 1004558444
#
# Processando: 'The Godfather: Part II' (1974)
#   -> Coluna 'Gross' preenchida com revenue: 102600000
#
# Processando: '12 Angry Men' (1957)
#   -> Coluna 'Gross' preenchida com revenue: 4360000
#
# Processando: 'The Lord of the Rings: The Return of the King' (2003)
#   -> Coluna 'Gross' preenchida com revenue: 1118888979
#
# Processando: 'Pulp Fiction' (1994)
#   -> Coluna 'Gross' preenchida com revenue: 213928762
#
# Processando: 'Schindler's List' (1993)
#   -> Coluna 'Gross' preenchida com revenue: 321365567
#
# Processando: 'Inception' (2010)
#   -> Coluna 'Gross' preenchida com revenue: 839030630
#
# Processando: 'Fight Club' (1999)
#   -> Coluna 'Gross' preenchida com revenue: 100853753
#
# Processando: 'The Lord of the Rings: The Fellowship of the Ring' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 871368364
#
# Processando: 'Forrest Gump' (1994)
#   -> Coluna 'Gross' preenchida com revenue: 677387716
#
# Processando: 'Il buono, il brutto, il cattivo' (1966)
#   -> Coluna 'Gross' preenchida com revenue: 38900000
#
# Processando: 'The Lord of the Rings: The Two Towers' (2002)
#   -> Coluna 'Gross' preenchida com revenue: 926287400
#
# Processando: 'The Matrix' (1999)
#   -> Coluna 'Gross' preenchida com revenue: 463517383
#
# Processando: 'Goodfellas' (1990)
#   -> Coluna 'Gross' preenchida com revenue: 46800000
#
# Processando: 'Star Wars: Episode V - The Empire Strikes Back' (1980)
#   -> Coluna 'Gross' preenchida com revenue: 538400000
#
# Processando: 'One Flew Over the Cuckoo's Nest' (1975)
#   -> Coluna 'Gross' preenchida com revenue: 108981275
#
# Processando: 'Hamilton' (2020)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Gisaengchung' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 257591776
#
# Processando: 'Soorarai Pottru' (2020)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Interstellar' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 746606706
#
# Processando: 'Cidade de Deus' (2002)
#   -> Coluna 'Gross' preenchida com revenue: 30641770
#
# Processando: 'Sen to Chihiro no kamikakushi' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 274925095
#
# Processando: 'Saving Private Ryan' (1998)
#   -> Coluna 'Gross' preenchida com revenue: 481840909
#
# Processando: 'The Green Mile' (1999)
#   -> Coluna 'Gross' preenchida com revenue: 286801374
#
# Processando: 'La vita è bella' (1997)
#   -> Coluna 'Gross' preenchida com revenue: 230098753
#
# Processando: 'Se7en' (1995)
#   -> Coluna 'Gross' preenchida com revenue: 327311859
#
# Processando: 'The Silence of the Lambs' (1991)
#   -> Coluna 'Gross' preenchida com revenue: 272742922
#
# Processando: 'Star Wars' (1977)
#   -> Coluna 'Gross' preenchida com revenue: 775398007
#
# Processando: 'Seppuku' (1962)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Shichinin no samurai' (1954)
#   -> Coluna 'Gross' preenchida com revenue: 105000000
#
# Processando: 'It's a Wonderful Life' (1946)
#   -> Coluna 'Gross' preenchida com revenue: 9644124
#
# Processando: 'Joker' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 1078958629
#
# Processando: 'Whiplash' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 50307484
#
# Processando: 'The Intouchables' (2011)
#   -> Coluna 'Gross' preenchida com revenue: 426590315
#
# Processando: 'The Prestige' (2006)
#   -> Coluna 'Gross' preenchida com revenue: 109676311
#
# Processando: 'The Departed' (2006)
#   -> Coluna 'Gross' preenchida com revenue: 291465000
#
# Processando: 'The Pianist' (2002)
#   -> Coluna 'Gross' preenchida com revenue: 120098945
#
# Processando: 'Gladiator' (2000)
#   -> Coluna 'Gross' preenchida com revenue: 465516248
#
# Processando: 'American History X' (1998)
#   -> Coluna 'Gross' preenchida com revenue: 23900000
#
# Processando: 'The Usual Suspects' (1995)
#   -> Coluna 'Gross' preenchida com revenue: 23300000
#
# Processando: 'Léon' (1994)
#   -> Coluna 'Gross' preenchida com revenue: 45284974
#
# Processando: 'The Lion King' (1994)
#   -> Coluna 'Gross' preenchida com revenue: 763455561
#
# Processando: 'Terminator 2: Judgment Day' (1991)
#   -> Coluna 'Gross' preenchida com revenue: 520000000
#
# Processando: 'Nuovo Cinema Paradiso' (1988)
#   -> Coluna 'Gross' preenchida com revenue: 12462062
#
# Processando: 'Hotaru no haka' (1988)
#   -> Coluna 'Gross' preenchida com revenue: 842132
#
# Processando: 'Back to the Future' (1985)
#   -> Coluna 'Gross' preenchida com revenue: 381109762
#
# Processando: 'Once Upon a Time in the West' (1968)
#   -> Coluna 'Gross' preenchida com revenue: 5380118
#
# Processando: 'Psycho' (1960)
#   -> Coluna 'Gross' preenchida com revenue: 50048065
#
# Processando: 'Casablanca' (1942)
#   -> Coluna 'Gross' preenchida com revenue: 10462500
#
# Processando: 'Modern Times' (1936)
#   -> Coluna 'Gross' preenchida com revenue: 1800000
#
# Processando: 'City Lights' (1931)
#   -> Coluna 'Gross' preenchida com revenue: 4250000
#
# Processando: 'Capharnaüm' (2018)
#   -> Coluna 'Gross' preenchida com revenue: 64978931
#
# Processando: 'Ayla: The Daughter of War' (2017)
#   -> Coluna 'Gross' preenchida com revenue: 21107423
#
# Processando: 'Vikram Vedha' (2017)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Kimi no na wa.' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 358000000
#
# Processando: 'Dangal' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 311000000
#
# Processando: 'Spider-Man: Into the Spider-Verse' (2018)
#   -> Coluna 'Gross' preenchida com revenue: 393602435
#
# Processando: 'Avengers: Endgame' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 2799439100
#
# Processando: 'Avengers: Infinity War' (2018)
#   -> Coluna 'Gross' preenchida com revenue: 2052415039
#
# Processando: 'Coco' (2017)
#   -> Coluna 'Gross' preenchida com revenue: 814641172
#
# Processando: 'Django Unchained' (2012)
#   -> Coluna 'Gross' preenchida com revenue: 425368238
#
# Processando: 'The Dark Knight Rises' (2012)
#   -> Coluna 'Gross' preenchida com revenue: 1081041287
#
# Processando: '3 Idiots' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 70000000
#
# Processando: 'Taare Zameen Par' (2007)
#   -> Coluna 'Gross' preenchida com revenue: 28430000
#
# Processando: 'WALL·E' (2008)
#   -> Coluna 'Gross' preenchida com revenue: 521311860
#
# Processando: 'The Lives of Others' (2006)
#   -> Coluna 'Gross' preenchida com revenue: 77672685
#
# Processando: 'Oldeuboi' (2003)
#   -> Coluna 'Gross' preenchida com revenue: 17500000
#
# Processando: 'Memento' (2000)
#   -> Coluna 'Gross' preenchida com revenue: 40047236
#
# Processando: 'Mononoke-hime' (1997)
#   -> Coluna 'Gross' preenchida com revenue: 176506186
#
# Processando: 'Once Upon a Time in America' (1984)
#   -> Coluna 'Gross' preenchida com revenue: 5500000
#
# Processando: 'Raiders of the Lost Ark' (1981)
#   -> Coluna 'Gross' preenchida com revenue: 389925971
#
# Processando: 'The Shining' (1980)
#   -> Coluna 'Gross' preenchida com revenue: 44781695
#
# Processando: 'Apocalypse Now' (1979)
#   -> Coluna 'Gross' preenchida com revenue: 150000000
#
# Processando: 'Alien' (1979)
#   -> Coluna 'Gross' preenchida com revenue: 104931801
#
# Processando: 'Anand' (1971)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Tengoku to jigoku' (1963)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb' (1964)
#   -> Coluna 'Gross' preenchida com revenue: 9500000
#
# Processando: 'Witness for the Prosecution' (1957)
#   -> Coluna 'Gross' preenchida com revenue: 9000000
#
# Processando: 'Paths of Glory' (1957)
#   -> Coluna 'Gross' preenchida com revenue: 1200000
#
# Processando: 'Rear Window' (1954)
#   -> Coluna 'Gross' preenchida com revenue: 37042336
#
# Processando: 'Sunset Blvd.' (1950)
#   -> Coluna 'Gross' preenchida com revenue: 5000000
#
# Processando: 'The Great Dictator' (1940)
#   -> Coluna 'Gross' preenchida com revenue: 11000000
#
# Processando: '1917' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 394638258
#
# Processando: 'Tumbbad' (2018)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Andhadhun' (2018)
#   -> Coluna 'Gross' preenchida com revenue: 40000000
#
# Processando: 'Drishyam' (2013)
#   -> Coluna 'Gross' preenchida com revenue: 12000000
#
# Processando: 'Jagten' (2012)
#   -> Coluna 'Gross' preenchida com revenue: 18300000
#
# Processando: 'Jodaeiye Nader az Simin' (2011)
#   -> Coluna 'Gross' preenchida com revenue: 24426169
#
# Processando: 'Incendies' (2010)
#   -> Coluna 'Gross' preenchida com revenue: 6788659
#
# Processando: 'Miracle in cell NO.7' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 28000000
#
# Processando: 'Babam ve Oglum' (2005)
#   -> Coluna 'Gross' preenchida com revenue: 4187299
#
# Processando: 'Inglourious Basterds' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 321457747
#
# Processando: 'Eternal Sunshine of the Spotless Mind' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 72258126
#
# Processando: 'Amélie' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 173921954
#
# Processando: 'Snatch' (2000)
#   -> Coluna 'Gross' preenchida com revenue: 83557872
#
# Processando: 'Requiem for a Dream' (2000)
#   -> Coluna 'Gross' preenchida com revenue: 7390108
#
# Processando: 'American Beauty' (1999)
#   -> Coluna 'Gross' preenchida com revenue: 356296601
#
# Processando: 'Good Will Hunting' (1997)
#   -> Coluna 'Gross' preenchida com revenue: 225900000
#
# Processando: 'Bacheha-Ye aseman' (1997)
#   -> Coluna 'Gross' preenchida com revenue: 925402
#
# Processando: 'Toy Story' (1995)
#   -> Coluna 'Gross' preenchida com revenue: 394436586
#
# Processando: 'Braveheart' (1995)
#   -> Coluna 'Gross' preenchida com revenue: 213216216
#
# Processando: 'Reservoir Dogs' (1992)
#   -> Coluna 'Gross' preenchida com revenue: 2859750
#
# Processando: 'Full Metal Jacket' (1987)
#   -> Coluna 'Gross' preenchida com revenue: 46357676
#
# Processando: 'Idi i smotri' (1985)
#   -> Coluna 'Gross' preenchida com revenue: 20929648
#
# Processando: 'Aliens' (1986)
#   -> Coluna 'Gross' preenchida com revenue: 183316455
#
# Processando: 'Amadeus' (1984)
#   -> Coluna 'Gross' preenchida com revenue: 90007557
#
# Processando: 'Scarface' (1983)
#   -> Coluna 'Gross' preenchida com revenue: 66023329
#
# Processando: 'Star Wars: Episode VI - Return of the Jedi' (1983)
#   -> Coluna 'Gross' preenchida com revenue: 572700000
#
# Processando: 'Das Boot' (1981)
#   -> Coluna 'Gross' preenchida com revenue: 85000000
#
# Processando: 'Taxi Driver' (1976)
#   -> Coluna 'Gross' preenchida com revenue: 28579636
#
# Processando: 'The Sting' (1973)
#   -> Coluna 'Gross' preenchida com revenue: 159616327
#
# Processando: 'A Clockwork Orange' (1971)
#   -> Coluna 'Gross' preenchida com revenue: 27033812
#
# Processando: '2001: A Space Odyssey' (1968)
#   -> Coluna 'Gross' preenchida com revenue: 71923560
#
# Processando: 'Per qualche dollaro in più' (1965)
#   -> Coluna 'Gross' preenchida com revenue: 15000000
#
# Processando: 'Lawrence of Arabia' (1962)
#   -> Coluna 'Gross' preenchida com revenue: 69995385
#
# Processando: 'The Apartment' (1960)
#   -> Coluna 'Gross' preenchida com revenue: 25000000
#
# Processando: 'North by Northwest' (1959)
#   -> Coluna 'Gross' preenchida com revenue: 13275000
#
# Processando: 'Vertigo' (1958)
#   -> Coluna 'Gross' preenchida com revenue: 7808900
#
# Processando: 'Singin' in the Rain' (1952)
#   -> Coluna 'Gross' preenchida com revenue: 7200000
#
# Processando: 'Ikiru' (1952)
#   -> Coluna 'Gross' preenchida com revenue: 55240
#
# Processando: 'Ladri di biciclette' (1948)
#   -> Coluna 'Gross' preenchida com revenue: 450159
#
# Processando: 'Double Indemnity' (1944)
#   -> Coluna 'Gross' preenchida com revenue: 2500000
#
# Processando: 'Citizen Kane' (1941)
#   -> Coluna 'Gross' preenchida com revenue: 23218000
#
# Processando: 'M - Eine Stadt sucht einen Mörder' (1931)
#   -> Coluna 'Gross' preenchida com revenue: 35274
#
# Processando: 'Metropolis' (1927)
#   -> Coluna 'Gross' preenchida com revenue: 1350322
#
# Processando: 'The Kid' (1921)
#   -> Coluna 'Gross' preenchida com revenue: 5450000
#
# Processando: 'Chhichhore' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 29353057
#
# Processando: 'Uri: The Surgical Strike' (2018)
#
# Processando: 'K.G.F: Chapter 1' (2018)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Green Book' (2018)
#   -> Coluna 'Gross' preenchida com revenue: 321752656
#
# Processando: 'Three Billboards Outside Ebbing, Missouri' (2017)
#   -> Coluna 'Gross' preenchida com revenue: 162729321
#
# Processando: 'Talvar' (2015)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Baahubali 2: The Conclusion' (2017)
#   -> Coluna 'Gross' preenchida com revenue: 280700000
#
# Processando: 'Klaus' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Drishyam' (2015)
#   -> Coluna 'Gross' preenchida com revenue: 18000000
#
# Processando: 'Queen' (2013)
#   -> Coluna 'Gross' preenchida com revenue: 17000000
#
# Processando: 'Mandariinid' (2013)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Bhaag Milkha Bhaag' (2013)
#   -> Coluna 'Gross' preenchida com revenue: 25000000
#
# Processando: 'Gangs of Wasseypur' (2012)
#   -> Coluna 'Gross' preenchida com revenue: 4100000
#
# Processando: 'Udaan' (2010)
#   -> Coluna 'Gross' preenchida com revenue: 520000
#
# Processando: 'Paan Singh Tomar' (2012)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'El secreto de sus ojos' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 33965843
#
# Processando: 'Warrior' (2011)
#   -> Coluna 'Gross' preenchida com revenue: 23300000
#
# Processando: 'Shutter Island' (2010)
#   -> Coluna 'Gross' preenchida com revenue: 294804195
#
# Processando: 'Up' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 735103954
#
# Processando: 'The Wolf of Wall Street' (2013)
#   -> Coluna 'Gross' preenchida com revenue: 407038432
#
# Processando: 'Chak De! India' (2007)
#   -> Coluna 'Gross' preenchida com revenue: 40000000
#
# Processando: 'There Will Be Blood' (2007)
#   -> Coluna 'Gross' preenchida com revenue: 77208711
#
# Processando: 'Pan's Labyrinth' (2006)
#   -> Coluna 'Gross' preenchida com revenue: 83258226
#
# Processando: 'Toy Story 3' (2010)
#   -> Coluna 'Gross' preenchida com revenue: 1067316101
#
# Processando: 'V for Vendetta' (2005)
#   -> Coluna 'Gross' preenchida com revenue: 134686457
#
# Processando: 'Rang De Basanti' (2006)
#   -> Coluna 'Gross' preenchida com revenue: 11502151
#
# Processando: 'Black' (2005)
#   -> Coluna 'Gross' preenchida com revenue: 8029469
#
# Processando: 'Batman Begins' (2005)
#   -> Coluna 'Gross' preenchida com revenue: 374218673
#
# Processando: 'Swades: We, the People' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 4800000
#
# Processando: 'Der Untergang' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 92181574
#
# Processando: 'Hauru no ugoku shiro' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 236049757
#
# Processando: 'A Beautiful Mind' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 316791257
#
# Processando: 'Hera Pheri' (2000)
#   -> Coluna 'Gross' preenchida com revenue: 4755000
#
# Processando: 'Lock, Stock and Two Smoking Barrels' (1998)
#   -> Coluna 'Gross' preenchida com revenue: 28356188
#
# Processando: 'L.A. Confidential' (1997)
#   -> Coluna 'Gross' preenchida com revenue: 126216940
#
# Processando: 'Eskiya' (1996)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Heat' (1995)
#   -> Coluna 'Gross' preenchida com revenue: 187400000
#
# Processando: 'Casino' (1995)
#   -> Coluna 'Gross' preenchida com revenue: 116112375
#
# Processando: 'Andaz Apna Apna' (1994)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Unforgiven' (1992)
#   -> Coluna 'Gross' preenchida com revenue: 159157447
#
# Processando: 'Indiana Jones and the Last Crusade' (1989)
#   -> Coluna 'Gross' preenchida com revenue: 474171806
#
# Processando: 'Dom za vesanje' (1988)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Tonari no Totoro' (1988)
#   -> Coluna 'Gross' preenchida com revenue: 41000000
#
# Processando: 'Die Hard' (1988)
#   -> Coluna 'Gross' preenchida com revenue: 140767956
#
# Processando: 'Ran' (1985)
#   -> Coluna 'Gross' preenchida com revenue: 23334156
#
# Processando: 'Raging Bull' (1980)
#   -> Coluna 'Gross' preenchida com revenue: 23380203
#
# Processando: 'Stalker' (1979)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Höstsonaten' (1978)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'The Message' (1976)
#   -> Coluna 'Gross' preenchida com revenue: 15000000
#
# Processando: 'Sholay' (1975)
#   -> Coluna 'Gross' preenchida com revenue: 4800000
#
# Processando: 'Monty Python and the Holy Grail' (1975)
#   -> Coluna 'Gross' preenchida com revenue: 5763644
#
# Processando: 'The Great Escape' (1963)
#   -> Coluna 'Gross' preenchida com revenue: 11700000
#
# Processando: 'To Kill a Mockingbird' (1962)
#   -> Coluna 'Gross' preenchida com revenue: 13129846
#
# Processando: 'Yôjinbô' (1961)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Judgment at Nuremberg' (1961)
#   -> Coluna 'Gross' preenchida com revenue: 10000000
#
# Processando: 'Some Like It Hot' (1959)
#   -> Coluna 'Gross' preenchida com revenue: 25000000
#
# Processando: 'Smultronstället' (1957)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Det sjunde inseglet' (1957)
#   -> Coluna 'Gross' preenchida com revenue: 311212
#
# Processando: 'Du rififi chez les hommes' (1955)
#   -> Coluna 'Gross' preenchida com revenue: 460000
#
# Processando: 'Dial M for Murder' (1954)
#   -> Coluna 'Gross' preenchida com revenue: 3000000
#
# Processando: 'Tôkyô monogatari' (1953)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Rashômon' (1950)
#   -> Coluna 'Gross' preenchida com revenue: 117668
#
# Processando: 'All About Eve' (1950)
#   -> Coluna 'Gross' preenchida com revenue: 8400000
#
# Processando: 'The Treasure of the Sierra Madre' (1948)
#   -> Coluna 'Gross' preenchida com revenue: 4307000
#
# Processando: 'To Be or Not to Be' (1942)
#   -> Coluna 'Gross' preenchida com revenue: 1500000
#
# Processando: 'The Gold Rush' (1925)
#   -> Coluna 'Gross' preenchida com revenue: 4000000
#
# Processando: 'Sherlock Jr.' (1924)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Portrait de la jeune fille en feu' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 9923127
#
# Processando: 'Pink' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Koe no katachi' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 30819442
#
# Processando: 'Contratiempo' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 30000000
#
# Processando: 'Ah-ga-ssi' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 38600000
#
# Processando: 'Mommy' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 3494070
#
# Processando: 'Haider' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 11500000
#
# Processando: 'Logan' (2017)
#   -> Coluna 'Gross' preenchida com revenue: 619021436
#
# Processando: 'Room' (2015)
#   -> Coluna 'Gross' preenchida com revenue: 35401758
#
# Processando: 'Relatos salvajes' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 31478893
#
# Processando: 'Soul' (2020)
#   -> Coluna 'Gross' preenchida com revenue: 121977511
#
# Processando: 'Kis Uykusu' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 4018705
#
# Processando: 'PK' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 118920000
#
# Processando: 'OMG: Oh My God!' (2012)
#   -> Coluna 'Gross' preenchida com revenue: 19000000
#
# Processando: 'The Grand Budapest Hotel' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 174600318
#
# Processando: 'Gone Girl' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 370890259
#
# Processando: 'Ôkami kodomo no Ame to Yuki' (2012)
#   -> Coluna 'Gross' preenchida com revenue: 55262158
#
# Processando: 'Hacksaw Ridge' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 175302354
#
# Processando: 'Inside Out' (2015)
#   -> Coluna 'Gross' preenchida com revenue: 857611174
#
# Processando: 'Barfi!' (2012)
#   -> Coluna 'Gross' preenchida com revenue: 2804874
#
# Processando: '12 Years a Slave' (2013)
#   -> Coluna 'Gross' preenchida com revenue: 187000000
#
# Processando: 'Rush' (2013)
#   -> Coluna 'Gross' preenchida com revenue: 90200000
#
# Processando: 'Ford v Ferrari' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 225508210
#
# Processando: 'Spotlight' (2015)
#   -> Coluna 'Gross' preenchida com revenue: 98690254
#
# Processando: 'Song of the Sea' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 857522
#
# Processando: 'Kahaani' (2012)
#   -> Coluna 'Gross' preenchida com revenue: 16000000
#
# Processando: 'Zindagi Na Milegi Dobara' (2011)
#   -> Coluna 'Gross' preenchida com revenue: 160000000
#
# Processando: 'Prisoners' (2013)
#   -> Coluna 'Gross' preenchida com revenue: 122126687
#
# Processando: 'Mad Max: Fury Road' (2015)
#   -> Coluna 'Gross' preenchida com revenue: 378858340
#
# Processando: 'A Wednesday' (2008)
#   -> Coluna 'Gross' preenchida com revenue: 3500000
#
# Processando: 'Gran Torino' (2008)
#   -> Coluna 'Gross' preenchida com revenue: 270000000
#
# Processando: 'Harry Potter and the Deathly Hallows: Part 2' (2011)
#   -> Coluna 'Gross' preenchida com revenue: 1341511219
#
# Processando: 'Okuribito' (2008)
#   -> Coluna 'Gross' preenchida com revenue: 69932387
#
# Processando: 'Hachi: A Dog's Tale' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 46800000
#
# Processando: 'Mary and Max' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 1740429
#
# Processando: 'How to Train Your Dragon' (2010)
#   -> Coluna 'Gross' preenchida com revenue: 495141736
#
# Processando: 'Into the Wild' (2007)
#   -> Coluna 'Gross' preenchida com revenue: 56255142
#
# Processando: 'No Country for Old Men' (2007)
#   -> Coluna 'Gross' preenchida com revenue: 171627166
#
# Processando: 'Lage Raho Munna Bhai' (2006)
#   -> Coluna 'Gross' preenchida com revenue: 31517561
#
# Processando: 'Million Dollar Baby' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 216763646
#
# Processando: 'Hotel Rwanda' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 38000000
#
# Processando: 'Taegukgi hwinalrimyeo' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Before Sunset' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 15992615
#
# Processando: 'Munna Bhai M.B.B.S.' (2003)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Salinui chueok' (2003)
#   -> Coluna 'Gross' preenchida com revenue: 26000000
#
# Processando: 'Dil Chahta Hai' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 4099000
#
# Processando: 'Kill Bill: Vol. 1' (2003)
#   -> Coluna 'Gross' preenchida com revenue: 180906076
#
# Processando: 'Finding Nemo' (2003)
#   -> Coluna 'Gross' preenchida com revenue: 940335536
#
# Processando: 'Catch Me If You Can' (2002)
#   -> Coluna 'Gross' preenchida com revenue: 352114312
#
# Processando: 'Amores perros' (2000)
#   -> Coluna 'Gross' preenchida com revenue: 20908467
#
# Processando: 'Monsters, Inc.' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 579700000
#
# Processando: 'Shin seiki Evangelion Gekijô-ban: Air/Magokoro wo, kimi ni' (1997)
#   -> Coluna 'Gross' preenchida com revenue: 20563523
#
# Processando: 'Lagaan: Once Upon a Time in India' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 8100000
#
# Processando: 'The Sixth Sense' (1999)
#   -> Coluna 'Gross' preenchida com revenue: 672800000
#
# Processando: 'La leggenda del pianista sull'oceano' (1998)
#   -> Coluna 'Gross' preenchida com revenue: 21057208
#
# Processando: 'The Truman Show' (1998)
#   -> Coluna 'Gross' preenchida com revenue: 264118712
#
# Processando: 'Crna macka, beli macor' (1998)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'The Big Lebowski' (1998)
#   -> Coluna 'Gross' preenchida com revenue: 47010480
#
# Processando: 'Fa yeung nin wah' (2000)
#
# Processando: 'Trainspotting' (1996)
#   -> Coluna 'Gross' preenchida com revenue: 71981823
#
# Processando: 'Fargo' (1996)
#   -> Coluna 'Gross' preenchida com revenue: 60611975
#
# Processando: 'Underground' (1995)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'La haine' (1995)
#   -> Coluna 'Gross' preenchida com revenue: 15300000
#
# Processando: 'Dilwale Dulhania Le Jayenge' (1995)
#   -> Coluna 'Gross' preenchida com revenue: 100000000
#
# Processando: 'Before Sunrise' (1995)
#   -> Coluna 'Gross' preenchida com revenue: 5987386
#
# Processando: 'Trois couleurs: Rouge' (1994)
#   -> Coluna 'Gross' preenchida com revenue: 4127033
#
# Processando: 'Chung Hing sam lam' (1994)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Jurassic Park' (1993)
#   -> Coluna 'Gross' preenchida com revenue: 920100000
#
# Processando: 'In the Name of the Father' (1993)
#   -> Coluna 'Gross' preenchida com revenue: 65796862
#
# Processando: 'Ba wang bie ji' (1993)
#   -> Coluna 'Gross' preenchida com revenue: 6400000
#
# Processando: 'Dà hóng denglong gaogao guà' (1991)
#   -> Coluna 'Gross' preenchida com revenue: 16600000
#
# Processando: 'Dead Poets Society' (1989)
#   -> Coluna 'Gross' preenchida com revenue: 235860116
#
# Processando: 'Stand by Me' (1986)
#   -> Coluna 'Gross' preenchida com revenue: 52300000
#
# Processando: 'Platoon' (1986)
#   -> Coluna 'Gross' preenchida com revenue: 138530565
#
# Processando: 'Paris, Texas' (1984)
#   -> Coluna 'Gross' preenchida com revenue: 2181987
#
# Processando: 'Kaze no tani no Naushika' (1984)
#   -> Coluna 'Gross' preenchida com revenue: 9016411
#
# Processando: 'The Thing' (1982)
#   -> Coluna 'Gross' preenchida com revenue: 19629760
#
# Processando: 'Pink Floyd: The Wall' (1982)
#   -> Coluna 'Gross' preenchida com revenue: 22244207
#
# Processando: 'Fitzcarraldo' (1982)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Fanny och Alexander' (1982)
#   -> Coluna 'Gross' preenchida com revenue: 6800000
#
# Processando: 'Blade Runner' (1982)
#   -> Coluna 'Gross' preenchida com revenue: 41722424
#
# Processando: 'The Elephant Man' (1980)
#   -> Coluna 'Gross' preenchida com revenue: 26000000
#
# Processando: 'Life of Brian' (1979)
#   -> Coluna 'Gross' preenchida com revenue: 20833252
#
# Processando: 'The Deer Hunter' (1978)
#   -> Coluna 'Gross' preenchida com revenue: 49000000
#
# Processando: 'Rocky' (1976)
#   -> Coluna 'Gross' preenchida com revenue: 225253184
#
# Processando: 'Network' (1976)
#   -> Coluna 'Gross' preenchida com revenue: 23700000
#
# Processando: 'Barry Lyndon' (1975)
#   -> Coluna 'Gross' preenchida com revenue: 31500000
#
# Processando: 'Zerkalo' (1975)
#   -> Coluna 'Gross' preenchida com revenue: 124367
#
# Processando: 'Chinatown' (1974)
#   -> Coluna 'Gross' preenchida com revenue: 30000000
#
# Processando: 'Paper Moon' (1973)
#   -> Coluna 'Gross' preenchida com revenue: 30900000
#
# Processando: 'Viskningar och rop' (1972)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Solaris' (1972)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Le samouraï' (1967)
#   -> Coluna 'Gross' preenchida com revenue: 215245
#
# Processando: 'Cool Hand Luke' (1967)
#   -> Coluna 'Gross' preenchida com revenue: 16217773
#
# Processando: 'Persona' (1966)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Andrei Rublev' (1966)
#   -> Coluna 'Gross' preenchida com revenue: 24173
#
# Processando: 'La battaglia di Algeri' (1966)
#   -> Coluna 'Gross' preenchida com revenue: 964028
#
# Processando: 'El ángel exterminador' (1962)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'What Ever Happened to Baby Jane?' (1962)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Sanjuro' (1962)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'The Man Who Shot Liberty Valance' (1962)
#   -> Coluna 'Gross' preenchida com revenue: 8000000
#
# Processando: 'Ivanovo detstvo' (1962)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Jungfrukällan' (1960)
#   -> Coluna 'Gross' preenchida com revenue: 700000
#
# Processando: 'Inherit the Wind' (1960)
#   -> Coluna 'Gross' preenchida com revenue: 2000000
#
# Processando: 'Les quatre cents coups' (1959)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Ben-Hur' (1959)
#   -> Coluna 'Gross' preenchida com revenue: 164000000
#
# Processando: 'Kakushi-toride no san-akunin' (1958)
#   -> Coluna 'Gross' preenchida com revenue: 57673
#
# Processando: 'Le notti di Cabiria' (1957)
#   -> Coluna 'Gross' preenchida com revenue: 752045
#
# Processando: 'Kumonosu-jô' (1957)
#   -> Coluna 'Gross' preenchida com revenue: 13422
#
# Processando: 'The Bridge on the River Kwai' (1957)
#   -> Coluna 'Gross' preenchida com revenue: 44908000
#
# Processando: 'On the Waterfront' (1954)
#   -> Coluna 'Gross' preenchida com revenue: 960000
#
# Processando: 'Le salaire de la peur' (1953)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Ace in the Hole' (1951)
#   -> Coluna 'Gross' preenchida com revenue: 1300000
#
# Processando: 'White Heat' (1949)
#   -> Coluna 'Gross' preenchida com revenue: 3483000
#
# Processando: 'The Third Man' (1949)
#   -> Coluna 'Gross' preenchida com revenue: 1226098
#
# Processando: 'The Red Shoes' (1948)
#   -> Coluna 'Gross' preenchida com revenue: 10000000
#
# Processando: 'The Shop Around the Corner' (1940)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Rebecca' (1940)
#   -> Coluna 'Gross' preenchida com revenue: 7592465
#
# Processando: 'Mr. Smith Goes to Washington' (1939)
#   -> Coluna 'Gross' preenchida com revenue: 9600000
#
# Processando: 'Gone with the Wind' (1939)
#   -> Coluna 'Gross' preenchida com revenue: 402352579
#
# Processando: 'La Grande Illusion' (1937)
#   -> Coluna 'Gross' preenchida com revenue: 172885
#
# Processando: 'It Happened One Night' (1934)
#   -> Coluna 'Gross' preenchida com revenue: 4500000
#
# Processando: 'La passion de Jeanne d'Arc' (1928)
#   -> Coluna 'Gross' preenchida com revenue: 18121
#
# Processando: 'The Circus' (1928)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Sunrise: A Song of Two Humans' (1927)
#   -> Coluna 'Gross' preenchida com revenue: 1636000
#
# Processando: 'The General' (1926)
#   -> Coluna 'Gross' preenchida com revenue: 1000000
#
# Processando: 'Das Cabinet des Dr. Caligari' (1920)
#   -> Coluna 'Gross' preenchida com revenue: 8811
#
# Processando: 'Badhaai ho' (2018)
#   -> Coluna 'Gross' preenchida com revenue: 39000000
#
# Processando: 'Togo' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Airlift' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 32000000
#
# Processando: 'Bajrangi Bhaijaan' (2015)
#   -> Coluna 'Gross' preenchida com revenue: 150000000
#
# Processando: 'Baby' (2015)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'La La Land' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 509183536
#
# Processando: 'Lion' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 140312928
#
# Processando: 'The Martian' (2015)
#   -> Coluna 'Gross' preenchida com revenue: 631058917
#
# Processando: 'Zootopia' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 1025521689
#
# Processando: 'Bãhubali: The Beginning' (2015)
#   -> Coluna 'Gross' preenchida com revenue: 90747520
#
# Processando: 'Kaguyahime no monogatari' (2013)
#   -> Coluna 'Gross' preenchida com revenue: 24366656
#
# Processando: 'Wonder' (2017)
#   -> Coluna 'Gross' preenchida com revenue: 315025930
#
# Processando: 'Gully Boy' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 28299498
#
# Processando: 'Special Chabbis' (2013)
#   -> Coluna 'Gross' preenchida com revenue: 18000000
#
# Processando: 'Short Term 12' (2013)
#   -> Coluna 'Gross' preenchida com revenue: 1645164
#
# Processando: 'Serbuan maut 2: Berandal' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 6566916
#
# Processando: 'The Imitation Game' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 233555708
#
# Processando: 'Guardians of the Galaxy' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 772776600
#
# Processando: 'Blade Runner 2049' (2017)
#   -> Coluna 'Gross' preenchida com revenue: 259239658
#
# Processando: 'Her' (2013)
#   -> Coluna 'Gross' preenchida com revenue: 47351251
#
# Processando: 'Bohemian Rhapsody' (2018)
#   -> Coluna 'Gross' preenchida com revenue: 910813521
#
# Processando: 'The Revenant' (2015)
#   -> Coluna 'Gross' preenchida com revenue: 532950503
#
# Processando: 'The Perks of Being a Wallflower' (2012)
#   -> Coluna 'Gross' preenchida com revenue: 33384127
#
# Processando: 'Tropa de Elite 2: O Inimigo Agora é Outro' (2010)
#   -> Coluna 'Gross' preenchida com revenue: 63027681
#
# Processando: 'The King's Speech' (2010)
#   -> Coluna 'Gross' preenchida com revenue: 414211549
#
# Processando: 'The Help' (2011)
#   -> Coluna 'Gross' preenchida com revenue: 216600000
#
# Processando: 'Deadpool' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 782837347
#
# Processando: 'Darbareye Elly' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Dev.D' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 7600000
#
# Processando: 'Yip Man' (2008)
#
# Processando: 'My Name Is Khan' (2010)
#   -> Coluna 'Gross' preenchida com revenue: 42345360
#
# Processando: 'Nefes: Vatan Sagolsun' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 13500000
#
# Processando: 'Slumdog Millionaire' (2008)
#   -> Coluna 'Gross' preenchida com revenue: 378400000
#
# Processando: 'Black Swan' (2010)
#   -> Coluna 'Gross' preenchida com revenue: 329398046
#
# Processando: 'Tropa de Elite' (2007)
#   -> Coluna 'Gross' preenchida com revenue: 14759148
#
# Processando: 'The Avengers' (2012)
#   -> Coluna 'Gross' preenchida com revenue: 1518815515
#
# Processando: 'Persepolis' (2007)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Dallas Buyers Club' (2013)
#   -> Coluna 'Gross' preenchida com revenue: 55736588
#
# Processando: 'The Pursuit of Happyness' (2006)
#   -> Coluna 'Gross' preenchida com revenue: 307077295
#
# Processando: 'Blood Diamond' (2006)
#   -> Coluna 'Gross' preenchida com revenue: 171700000
#
# Processando: 'The Bourne Ultimatum' (2007)
#   -> Coluna 'Gross' preenchida com revenue: 442824138
#
# Processando: 'Bin-jip' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 3403957
#
# Processando: 'Sin City' (2005)
#   -> Coluna 'Gross' preenchida com revenue: 158733820
#
# Processando: 'Le scaphandre et le papillon' (2007)
#   -> Coluna 'Gross' preenchida com revenue: 19777647
#
# Processando: 'G.O.R.A.' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Ratatouille' (2007)
#   -> Coluna 'Gross' preenchida com revenue: 623726000
#
# Processando: 'Casino Royale' (2006)
#   -> Coluna 'Gross' preenchida com revenue: 599045960
#
# Processando: 'Kill Bill: Vol. 2' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 152159461
#
# Processando: 'Vozvrashchenie' (2003)
#   -> Coluna 'Gross' preenchida com revenue: 8482993
#
# Processando: 'Bom Yeoareum Gaeul Gyeoul Geurigo Bom' (2003)
#   -> Coluna 'Gross' preenchida com revenue: 8945072
#
# Processando: 'Mar adentro' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Cinderella Man' (2005)
#   -> Coluna 'Gross' preenchida com revenue: 108539911
#
# Processando: 'Kal Ho Naa Ho' (2003)
#   -> Coluna 'Gross' preenchida com revenue: 13214520
#
# Processando: 'Mou gaan dou' (2002)
#   -> Coluna 'Gross' preenchida com revenue: 8836958
#
# Processando: 'Pirates of the Caribbean: The Curse of the Black Pearl' (2003)
#   -> Coluna 'Gross' preenchida com revenue: 655011224
#
# Processando: 'Big Fish' (2003)
#   -> Coluna 'Gross' preenchida com revenue: 123200000
#
# Processando: 'The Incredibles' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 631442092
#
# Processando: 'Yeopgijeogin geunyeo' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 32000000
#
# Processando: 'Dogville' (2003)
#   -> Coluna 'Gross' preenchida com revenue: 16690617
#
# Processando: 'Vizontele' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Donnie Darko' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 7500000
#
# Processando: 'Magnolia' (1999)
#   -> Coluna 'Gross' preenchida com revenue: 48500000
#
# Processando: 'Dancer in the Dark' (2000)
#   -> Coluna 'Gross' preenchida com revenue: 40061153
#
# Processando: 'The Straight Story' (1999)
#   -> Coluna 'Gross' preenchida com revenue: 6418028
#
# Processando: 'Pâfekuto burû' (1997)
#   -> Coluna 'Gross' preenchida com revenue: 112536
#
# Processando: 'Festen' (1998)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Central do Brasil' (1998)
#   -> Coluna 'Gross' preenchida com revenue: 5596708
#
# Processando: 'The Iron Giant' (1999)
#   -> Coluna 'Gross' preenchida com revenue: 23300000
#
# Processando: 'Knockin' on Heaven's Door' (1997)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Sling Blade' (1996)
#   -> Coluna 'Gross' preenchida com revenue: 34100000
#
# Processando: 'Secrets & Lies' (1996)
#   -> Coluna 'Gross' preenchida com revenue: 13417292
#
# Processando: 'Twelve Monkeys' (1995)
#   -> Coluna 'Gross' preenchida com revenue: 168841459
#
# Processando: 'Kôkaku Kidôtai' (1995)
#
# Processando: 'The Nightmare Before Christmas' (1993)
#   -> Coluna 'Gross' preenchida com revenue: 75634409
#
# Processando: 'Groundhog Day' (1993)
#   -> Coluna 'Gross' preenchida com revenue: 71108778
#
# Processando: 'Bound by Honor' (1993)
#   -> Coluna 'Gross' preenchida com revenue: 4500000
#
# Processando: 'Scent of a Woman' (1992)
#   -> Coluna 'Gross' preenchida com revenue: 134100000
#
# Processando: 'Aladdin' (1992)
#   -> Coluna 'Gross' preenchida com revenue: 504050219
#
# Processando: 'JFK' (1991)
#   -> Coluna 'Gross' preenchida com revenue: 205405498
#
# Processando: 'Beauty and the Beast' (1991)
#   -> Coluna 'Gross' preenchida com revenue: 424967620
#
# Processando: 'Dances with Wolves' (1990)
#   -> Coluna 'Gross' preenchida com revenue: 424208848
#
# Processando: 'Do the Right Thing' (1989)
#   -> Coluna 'Gross' preenchida com revenue: 37300000
#
# Processando: 'Rain Man' (1988)
#   -> Coluna 'Gross' preenchida com revenue: 354825435
#
# Processando: 'Akira' (1988)
#   -> Coluna 'Gross' preenchida com revenue: 49000000
#
# Processando: 'The Princess Bride' (1987)
#   -> Coluna 'Gross' preenchida com revenue: 30900000
#
# Processando: 'Der Himmel über Berlin' (1987)
#   -> Coluna 'Gross' preenchida com revenue: 3210139
#
# Processando: 'Au revoir les enfants' (1987)
#   -> Coluna 'Gross' preenchida com revenue: 4542825
#
# Processando: 'Tenkû no shiro Rapyuta' (1986)
#   -> Coluna 'Gross' preenchida com revenue: 5228752
#
# Processando: 'The Terminator' (1984)
#   -> Coluna 'Gross' preenchida com revenue: 78371200
#
# Processando: 'Gandhi' (1982)
#   -> Coluna 'Gross' preenchida com revenue: 77737889
#
# Processando: 'Kagemusha' (1980)
#   -> Coluna 'Gross' preenchida com revenue: 4000000
#
# Processando: 'Being There' (1979)
#   -> Coluna 'Gross' preenchida com revenue: 30177511
#
# Processando: 'Annie Hall' (1977)
#   -> Coluna 'Gross' preenchida com revenue: 43989445
#
# Processando: 'Jaws' (1975)
#   -> Coluna 'Gross' preenchida com revenue: 470653000
#
# Processando: 'Dog Day Afternoon' (1975)
#   -> Coluna 'Gross' preenchida com revenue: 46665856
#
# Processando: 'Young Frankenstein' (1974)
#   -> Coluna 'Gross' preenchida com revenue: 86273333
#
# Processando: 'Papillon' (1973)
#   -> Coluna 'Gross' preenchida com revenue: 53267000
#
# Processando: 'The Exorcist' (1973)
#   -> Coluna 'Gross' preenchida com revenue: 441306145
#
# Processando: 'Sleuth' (1972)
#   -> Coluna 'Gross' preenchida com revenue: 5750000
#
# Processando: 'The Last Picture Show' (1971)
#   -> Coluna 'Gross' preenchida com revenue: 29133000
#
# Processando: 'Fiddler on the Roof' (1971)
#   -> Coluna 'Gross' preenchida com revenue: 83304330
#
# Processando: 'Il conformista' (1970)
#   -> Coluna 'Gross' preenchida com revenue: 233493
#
# Processando: 'Butch Cassidy and the Sundance Kid' (1969)
#   -> Coluna 'Gross' preenchida com revenue: 102308889
#
# Processando: 'Rosemary's Baby' (1968)
#   -> Coluna 'Gross' preenchida com revenue: 33395426
#
# Processando: 'Planet of the Apes' (1968)
#   -> Coluna 'Gross' preenchida com revenue: 32589624
#
# Processando: 'The Graduate' (1967)
#   -> Coluna 'Gross' preenchida com revenue: 104945305
#
# Processando: 'Who's Afraid of Virginia Woolf?' (1966)
#   -> Coluna 'Gross' preenchida com revenue: 33736689
#
# Processando: 'The Sound of Music' (1965)
#   -> Coluna 'Gross' preenchida com revenue: 286214286
#
# Processando: 'Doctor Zhivago' (1965)
#   -> Coluna 'Gross' preenchida com revenue: 111858363
#
# Processando: 'Per un pugno di dollari' (1964)
#   -> Coluna 'Gross' preenchida com revenue: 14500000
#
# Processando: '8½' (1963)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Vivre sa vie: Film en douze tableaux' (1962)
#   -> Coluna 'Gross' preenchida com revenue: 24517
#
# Processando: 'The Hustler' (1961)
#   -> Coluna 'Gross' preenchida com revenue: 7600000
#
# Processando: 'La dolce vita' (1960)
#   -> Coluna 'Gross' preenchida com revenue: 19647000
#
# Processando: 'Rio Bravo' (1959)
#   -> Coluna 'Gross' preenchida com revenue: 5750000
#
# Processando: 'Anatomy of a Murder' (1959)
#   -> Coluna 'Gross' preenchida com revenue: 8000000
#
# Processando: 'Touch of Evil' (1958)
#   -> Coluna 'Gross' preenchida com revenue: 2247500
#
# Processando: 'Cat on a Hot Tin Roof' (1958)
#   -> Coluna 'Gross' preenchida com revenue: 17570324
#
# Processando: 'Sweet Smell of Success' (1957)
#   -> Coluna 'Gross' preenchida com revenue: 2500000
#
# Processando: 'The Killing' (1956)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'The Night of the Hunter' (1955)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'La Strada' (1954)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Les diaboliques' (1955)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Stalag 17' (1953)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Roman Holiday' (1953)
#   -> Coluna 'Gross' preenchida com revenue: 12000000
#
# Processando: 'A Streetcar Named Desire' (1951)
#   -> Coluna 'Gross' preenchida com revenue: 8000000
#
# Processando: 'In a Lonely Place' (1950)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Kind Hearts and Coronets' (1949)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Rope' (1948)
#   -> Coluna 'Gross' preenchida com revenue: 2200000
#
# Processando: 'Out of the Past' (1947)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Brief Encounter' (1945)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Laura' (1944)
#   -> Coluna 'Gross' preenchida com revenue: 2000000
#
# Processando: 'The Best Years of Our Lives' (1946)
#   -> Coluna 'Gross' preenchida com revenue: 23650000
#
# Processando: 'Arsenic and Old Lace' (1942)
#
# Processando: 'The Maltese Falcon' (1941)
#   -> Coluna 'Gross' preenchida com revenue: 1772000
#
# Processando: 'The Grapes of Wrath' (1940)
#   -> Coluna 'Gross' preenchida com revenue: 1591000
#
# Processando: 'The Wizard of Oz' (1939)
#   -> Coluna 'Gross' preenchida com revenue: 33754967
#
# Processando: 'La règle du jeu' (1939)
#   -> Coluna 'Gross' preenchida com revenue: 273520
#
# Processando: 'The Thin Man' (1934)
#   -> Coluna 'Gross' preenchida com revenue: 1423000
#
# Processando: 'All Quiet on the Western Front' (1930)
#   -> Coluna 'Gross' preenchida com revenue: 3270000
#
# Processando: 'Bronenosets Potemkin' (1925)
#   -> Coluna 'Gross' preenchida com revenue: 45100
#
# Processando: 'Knives Out' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 312897920
#
# Processando: 'Dil Bechara' (2020)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Manbiki kazoku' (2018)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Marriage Story' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 2300000
#
# Processando: 'Call Me by Your Name' (2017)
#   -> Coluna 'Gross' preenchida com revenue: 43143046
#
# Processando: 'I, Daniel Blake' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 15793051
#
# Processando: 'Isle of Dogs' (2018)
#   -> Coluna 'Gross' preenchida com revenue: 64337744
#
# Processando: 'Hunt for the Wilderpeople' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 23900000
#
# Processando: 'Captain Fantastic' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 23123592
#
# Processando: 'Sing Street' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 13624522
#
# Processando: 'Thor: Ragnarok' (2017)
#   -> Coluna 'Gross' preenchida com revenue: 855301806
#
# Processando: 'Nightcrawler' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 47425835
#
# Processando: 'Jojo Rabbit' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 82468705
#
# Processando: 'Arrival' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 203388186
#
# Processando: 'Star Wars: Episode VII - The Force Awakens' (2015)
#   -> Coluna 'Gross' preenchida com revenue: 2068223624
#
# Processando: 'Before Midnight' (2013)
#   -> Coluna 'Gross' preenchida com revenue: 11176469
#
# Processando: 'X-Men: Days of Future Past' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 747862775
#
# Processando: 'Bir Zamanlar Anadolu'da' (2011)
#   -> Coluna 'Gross' preenchida com revenue: 138730
#
# Processando: 'The Artist' (2011)
#   -> Coluna 'Gross' preenchida com revenue: 133432856
#
# Processando: 'Edge of Tomorrow' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 370541256
#
# Processando: 'Amour' (2012)
#   -> Coluna 'Gross' preenchida com revenue: 29800000
#
# Processando: 'The Irishman' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 968853
#
# Processando: 'Un prophète' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 17874044
#
# Processando: 'Moon' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 9760104
#
# Processando: 'Låt den rätte komma in' (2008)
#   -> Coluna 'Gross' preenchida com revenue: 10785801
#
# Processando: 'District 9' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 210888950
#
# Processando: 'The Wrestler' (2008)
#   -> Coluna 'Gross' preenchida com revenue: 44734660
#
# Processando: 'Jab We Met' (2007)
#   -> Coluna 'Gross' preenchida com revenue: 10065630
#
# Processando: 'Boyhood' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 48137666
#
# Processando: '4 luni, 3 saptamâni si 2 zile' (2007)
#   -> Coluna 'Gross' preenchida com revenue: 1185783
#
# Processando: 'Star Trek' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 386839614
#
# Processando: 'In Bruges' (2008)
#   -> Coluna 'Gross' preenchida com revenue: 34533783
#
# Processando: 'The Man from Earth' (2007)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Letters from Iwo Jima' (2006)
#   -> Coluna 'Gross' preenchida com revenue: 68673228
#
# Processando: 'The Fall' (2006)
#   -> Coluna 'Gross' preenchida com revenue: 3984390
#
# Processando: 'Life of Pi' (2012)
#   -> Coluna 'Gross' preenchida com revenue: 609016565
#
# Processando: 'Fantastic Mr. Fox' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 46471023
#
# Processando: 'C.R.A.Z.Y.' (2005)
#   -> Coluna 'Gross' preenchida com revenue: 3692417
#
# Processando: 'Les choristes' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 83600000
#
# Processando: 'Iron Man' (2008)
#   -> Coluna 'Gross' preenchida com revenue: 585174222
#
# Processando: 'Shaun of the Dead' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 39396175
#
# Processando: 'Gegen die Wand' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 11030861
#
# Processando: 'Mystic River' (2003)
#   -> Coluna 'Gross' preenchida com revenue: 156800000
#
# Processando: 'Harry Potter and the Prisoner of Azkaban' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 789804554
#
# Processando: 'Ying xiong' (2002)
#   -> Coluna 'Gross' preenchida com revenue: 177394432
#
# Processando: 'Hable con ella' (2002)
#   -> Coluna 'Gross' preenchida com revenue: 64803131
#
# Processando: 'No Man's Land' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 4858869
#
# Processando: 'Cowboy Bebop: Tengoku no tobira' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'The Bourne Identity' (2002)
#   -> Coluna 'Gross' preenchida com revenue: 214034224
#
# Processando: 'Nueve reinas' (2000)
#   -> Coluna 'Gross' preenchida com revenue: 12413888
#
# Processando: 'Children of Men' (2006)
#   -> Coluna 'Gross' preenchida com revenue: 70595464
#
# Processando: 'Almost Famous' (2000)
#   -> Coluna 'Gross' preenchida com revenue: 47386287
#
# Processando: 'Mulholland Dr.' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 20289986
#
# Processando: 'Toy Story 2' (1999)
#   -> Coluna 'Gross' preenchida com revenue: 497375381
#
# Processando: 'Boogie Nights' (1997)
#   -> Coluna 'Gross' preenchida com revenue: 43101594
#
# Processando: 'Mimi wo sumaseba' (1995)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Once Were Warriors' (1994)
#   -> Coluna 'Gross' preenchida com revenue: 6700000
#
# Processando: 'True Romance' (1993)
#   -> Coluna 'Gross' preenchida com revenue: 12600000
#
# Processando: 'Trois couleurs: Bleu' (1993)
#   -> Coluna 'Gross' preenchida com revenue: 1527572
#
# Processando: 'Jûbê ninpûchô' (1993)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Carlito's Way' (1993)
#   -> Coluna 'Gross' preenchida com revenue: 63848322
#
# Processando: 'Edward Scissorhands' (1990)
#   -> Coluna 'Gross' preenchida com revenue: 86024005
#
# Processando: 'My Left Foot: The Story of Christy Brown' (1989)
#   -> Coluna 'Gross' preenchida com revenue: 14743391
#
# Processando: 'Crimes and Misdemeanors' (1989)
#   -> Coluna 'Gross' preenchida com revenue: 18254702
#
# ...
#
# Processando: 'Fried Green Tomatoes' (1991)
#   -> Coluna 'Gross' preenchida com revenue: 119418501
#
# Processando: 'Barton Fink' (1991)
#   -> Coluna 'Gross' preenchida com revenue: 6153939
#
# Processando: 'Miller's Crossing' (1990)
#   -> Coluna 'Gross' preenchida com revenue: 5080409
#
# Processando: 'Who Framed Roger Rabbit' (1988)
#   -> Coluna 'Gross' preenchida com revenue: 329800000
#
# Processando: 'Spoorloos' (1988)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Withnail & I' (1987)
#   -> Coluna 'Gross' preenchida com revenue: 1544889
#
# Processando: 'The Last Emperor' (1987)
#   -> Coluna 'Gross' preenchida com revenue: 44000000
#
# Processando: 'Empire of the Sun' (1987)
#   -> Coluna 'Gross' preenchida com revenue: 66700000
#
# Processando: 'Der Name der Rose' (1986)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Blue Velvet' (1986)
#   -> Coluna 'Gross' preenchida com revenue: 8636706
#
# Processando: 'The Purple Rose of Cairo' (1985)
#   -> Coluna 'Gross' preenchida com revenue: 10631333
#
# Processando: 'After Hours' (1985)
#   -> Coluna 'Gross' preenchida com revenue: 10609321
#
# Processando: 'Zelig' (1983)
#   -> Coluna 'Gross' preenchida com revenue: 11798616
#
# Processando: 'The Verdict' (1982)
#   -> Coluna 'Gross' preenchida com revenue: 53977250
#
# Processando: 'Star Trek II: The Wrath of Khan' (1982)
#   -> Coluna 'Gross' preenchida com revenue: 96594943
#
# Processando: 'First Blood' (1982)
#   -> Coluna 'Gross' preenchida com revenue: 125212904
#
# Processando: 'Ordinary People' (1980)
#   -> Coluna 'Gross' preenchida com revenue: 54766923
#
# Processando: 'Airplane!' (1980)
#   -> Coluna 'Gross' preenchida com revenue: 83453539
#
# Processando: 'Rupan sansei: Kariosutoro no shiro' (1979)
#   -> Coluna 'Gross' preenchida com revenue: 8194857
#
# Processando: 'Halloween' (1978)
#   -> Coluna 'Gross' preenchida com revenue: 70260597
#
# Processando: 'Le locataire' (1976)
#   -> Coluna 'Gross' preenchida com revenue: 5100000
#
# Processando: 'Love and Death' (1975)
#   -> Coluna 'Gross' preenchida com revenue: 20173742
#
# Processando: 'The Taking of Pelham One Two Three' (1974)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Blazing Saddles' (1974)
#   -> Coluna 'Gross' preenchida com revenue: 119500000
#
# Processando: 'Serpico' (1973)
#   -> Coluna 'Gross' preenchida com revenue: 29800000
#
# Processando: 'Enter the Dragon' (1973)
#   -> Coluna 'Gross' preenchida com revenue: 400000000
#
# Processando: 'Deliverance' (1972)
#   -> Coluna 'Gross' preenchida com revenue: 46122355
#
# Processando: 'The French Connection' (1971)
#   -> Coluna 'Gross' preenchida com revenue: 41200000
#
# Processando: 'Dirty Harry' (1971)
#   -> Coluna 'Gross' preenchida com revenue: 35976000
#
# Processando: 'Where Eagles Dare' (1968)
#   -> Coluna 'Gross' preenchida com revenue: 21000000
#
# Processando: 'The Odd Couple' (1968)
#   -> Coluna 'Gross' preenchida com revenue: 44527234
#
# Processando: 'The Dirty Dozen' (1967)
#   -> Coluna 'Gross' preenchida com revenue: 45300000
#
# Processando: 'Belle de jour' (1967)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'A Man for All Seasons' (1966)
#   -> Coluna 'Gross' preenchida com revenue: 28350000
#
# Processando: 'Repulsion' (1965)
#   -> Coluna 'Gross' preenchida com revenue: 3100000
#
# Processando: 'Zulu' (1964)
#   -> Coluna 'Gross' preenchida com revenue: 8000000
#
# Processando: 'Goldfinger' (1964)
#   -> Coluna 'Gross' preenchida com revenue: 124900000
#
# Processando: 'The Birds' (1963)
#   -> Coluna 'Gross' preenchida com revenue: 11500000
#
# Processando: 'Cape Fear' (1962)
#   -> Coluna 'Gross' preenchida com revenue: 103000000
#
# Processando: 'Peeping Tom' (1960)
#   -> Coluna 'Gross' preenchida com revenue: 83957
#
# Processando: 'The Magnificent Seven' (1960)
#   -> Coluna 'Gross' preenchida com revenue: 4905000
#
# Processando: 'Les yeux sans visage' (1960)
#   -> Coluna 'Gross' preenchida com revenue: 58656
#
# Processando: 'Invasion of the Body Snatchers' (1956)
#   -> Coluna 'Gross' preenchida com revenue: 3000000
#
# Processando: 'Rebel Without a Cause' (1955)
#   -> Coluna 'Gross' preenchida com revenue: 4500000
#
# Processando: 'The Ladykillers' (1955)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Sabrina' (1954)
#   -> Coluna 'Gross' preenchida com revenue: 10000000
#
# Processando: 'The Quiet Man' (1952)
#   -> Coluna 'Gross' preenchida com revenue: 3800000
#
# Processando: 'The Day the Earth Stood Still' (1951)
#   -> Coluna 'Gross' preenchida com revenue: 1850000
#
# Processando: 'The African Queen' (1951)
#   -> Coluna 'Gross' preenchida com revenue: 10750000
#
# Processando: 'Gilda' (1946)
#   -> Coluna 'Gross' preenchida com revenue: 6000000
#
# Processando: 'Fantasia' (1940)
#   -> Coluna 'Gross' preenchida com revenue: 76411819
#
# Processando: 'The Invisible Man' (1933)
#   -> Coluna 'Gross' preenchida com revenue: 27105
#
# Processando: 'Dark Waters' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 13601384
#
# Processando: 'Searching' (2018)
#   -> Coluna 'Gross' preenchida com revenue: 75462037
#
# Processando: 'Once Upon a Time... in Hollywood' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 392105159
#
# Processando: 'Nelyubov' (2017)
#   -> Coluna 'Gross' preenchida com revenue: 3925992
#
# Processando: 'The Florida Project' (2017)
#   -> Coluna 'Gross' preenchida com revenue: 11303040
#
# Processando: 'Just Mercy' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 50401502
#
# Processando: 'Gifted' (2017)
#   -> Coluna 'Gross' preenchida com revenue: 40300000
#
# Processando: 'The Peanut Butter Falcon' (2019)
#   -> Coluna 'Gross' preenchida com revenue: 23712097
#
# Processando: 'Victoria' (2015)
#   -> Coluna 'Gross' preenchida com revenue: 3191971
#
# Processando: 'Mustang' (2015)
#   -> Coluna 'Gross' preenchida com revenue: 5300000
#
# Processando: 'Guardians of the Galaxy Vol. 2' (2017)
#   -> Coluna 'Gross' preenchida com revenue: 863756051
#
# Processando: 'Baby Driver' (2017)
#   -> Coluna 'Gross' preenchida com revenue: 226945087
#
# Processando: 'Only the Brave' (2017)
#   -> Coluna 'Gross' preenchida com revenue: 25754775
#
# Processando: 'Bridge of Spies' (2015)
#   -> Coluna 'Gross' preenchida com revenue: 165478348
#
# Processando: 'Incredibles 2' (2018)
#   -> Coluna 'Gross' preenchida com revenue: 1243225667
#
# Processando: 'Moana' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 690860472
#
# Processando: 'Sicario' (2015)
#   -> Coluna 'Gross' preenchida com revenue: 84997446
#
# Processando: 'Creed' (2015)
#   -> Coluna 'Gross' preenchida com revenue: 173600000
#
# Processando: 'Leviafan' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 4396821
#
# Processando: 'Hell or High Water' (2016)
#   -> Coluna 'Gross' preenchida com revenue: 37600000
#
# Processando: 'Philomena' (2013)
#   -> Coluna 'Gross' preenchida com revenue: 100100000
#
# Processando: 'Dawn of the Planet of the Apes' (2014)
#   -> Coluna 'Gross' preenchida com revenue: 710644566
#
# Processando: 'El cuerpo' (2012)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Serbuan maut' (2011)
#   -> Coluna 'Gross' preenchida com revenue: 9148519
#
# Processando: 'End of Watch' (2012)
#   -> Coluna 'Gross' preenchida com revenue: 55078146
#
# Processando: 'Kari-gurashi no Arietti' (2010)
#   -> Coluna 'Gross' preenchida com revenue: 149660003
#
# Processando: 'A Star Is Born' (2018)
#   -> Coluna 'Gross' preenchida com revenue: 436388866
#
# Processando: 'True Grit' (2010)
#   -> Coluna 'Gross' preenchida com revenue: 252300000
#
# Processando: 'Hævnen' (2010)
#   -> Coluna 'Gross' preenchida com revenue: 13004198
#
# Processando: 'Despicable Me' (2010)
#   -> Coluna 'Gross' preenchida com revenue: 543284256
#
# Processando: '50/50' (2011)
#   -> Coluna 'Gross' preenchida com revenue: 39187783
#
# Processando: 'Kick-Ass' (2010)
#   -> Coluna 'Gross' preenchida com revenue: 96188903
#
# Processando: 'Celda 211' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 19300483
#
# Processando: 'Moneyball' (2011)
#   -> Coluna 'Gross' preenchida com revenue: 110206216
#
# Processando: 'La piel que habito' (2011)
#   -> Coluna 'Gross' preenchida com revenue: 33750478
#
# Processando: 'Zombieland' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 102391540
#
# Processando: 'Die Welle' (2008)
#   -> Coluna 'Gross' preenchida com revenue: 32350637
#
# Processando: 'Sherlock Holmes' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 524028679
#
# Processando: 'The Blind Side' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 309231694
#
# Processando: 'The Visitor' (2007)
#   -> Coluna 'Gross' preenchida com revenue: 18197518
#
# Processando: 'Seven Pounds' (2008)
#   -> Coluna 'Gross' preenchida com revenue: 168167691
#
# Processando: 'Eastern Promises' (2007)
#   -> Coluna 'Gross' preenchida com revenue: 56106607
#
# Processando: 'Stardust' (2007)
#   -> Coluna 'Gross' preenchida com revenue: 137500000
#
# Processando: 'The Secret of Kells' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 1803412
#
# Processando: 'Inside Man' (2006)
#   -> Coluna 'Gross' preenchida com revenue: 186003591
#
# Processando: 'Gone Baby Gone' (2007)
#   -> Coluna 'Gross' preenchida com revenue: 34600000
#
# Processando: 'La Vie En Rose' (2007)
#   -> Coluna 'Gross' preenchida com revenue: 86274793
#
# Processando: 'Huo Yuan Jia' (2006)
#   -> Coluna 'Gross' preenchida com revenue: 68072848
#
# Processando: 'The Illusionist' (2006)
#   -> Coluna 'Gross' preenchida com revenue: 87892388
#
# Processando: 'Dead Man's Shoes' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Harry Potter and the Half-Blood Prince' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 933959197
#
# Processando: '300' (2006)
#   -> Coluna 'Gross' preenchida com revenue: 456082343
#
# Processando: 'Match Point' (2005)
#   -> Coluna 'Gross' preenchida com revenue: 85306374
#
# Processando: 'Watchmen' (2009)
#   -> Coluna 'Gross' preenchida com revenue: 185258983
#
# Processando: 'Lord of War' (2005)
#   -> Coluna 'Gross' preenchida com revenue: 72600000
#
# Processando: 'Saw' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 104045735
#
# Processando: 'Synecdoche, New York' (2008)
#   -> Coluna 'Gross' preenchida com revenue: 4383538
#
# Processando: 'Mysterious Skin' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 2148548
#
# Processando: 'Jeux d'enfants' (2003)
#   -> Coluna 'Gross' preenchida com revenue: 8561072
#
# Processando: 'Un long dimanche de fiançailles' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'The Station Agent' (2003)
#   -> Coluna 'Gross' preenchida com revenue: 8701337
#
# Processando: '21 Grams' (2003)
#   -> Coluna 'Gross' preenchida com revenue: 60427839
#
# Processando: 'Boksuneun naui geot' (2002)
#   -> Coluna 'Gross' preenchida com revenue: 1954937
#
# Processando: 'Finding Neverland' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 116766556
#
# Processando: '25th Hour' (2002)
#   -> Coluna 'Gross' preenchida com revenue: 23932055
#
# Processando: 'The Butterfly Effect' (2004)
#   -> Coluna 'Gross' preenchida com revenue: 96800000
#
# Processando: '28 Days Later...' (2002)
#   -> Coluna 'Gross' preenchida com revenue: 85032676
#
# Processando: 'Batoru rowaiaru' (2000)
#
# Processando: 'The Royal Tenenbaums' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 71441250
#
# Processando: 'Y tu mamá también' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 33600000
#
# Processando: 'Harry Potter and the Sorcerer's Stone' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 976475550
#
# Processando: 'The Others' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 210002906
#
# Processando: 'Blow' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 83300000
#
# Processando: 'Enemy at the Gates' (2001)
#   -> Coluna 'Gross' preenchida com revenue: 96976270
#
# Processando: 'Minority Report' (2002)
#   -> Coluna 'Gross' preenchida com revenue: 358372926
#
# Processando: 'The Hurricane' (1999)
#   -> Coluna 'Gross' preenchida com revenue: 73956241
#
# Processando: 'American Psycho' (2000)
#   -> Coluna 'Gross' preenchida com revenue: 34300000
#
# Processando: 'Lola rennt' (1998)
#   -> Coluna 'Gross' preenchida com revenue: 7660911
#
# Processando: 'The Thin Red Line' (1998)
#   -> Coluna 'Gross' preenchida com revenue: 98126565
#
# Processando: 'Mulan' (1998)
#   -> Coluna 'Gross' preenchida com revenue: 304320254
#
# Processando: 'Fear and Loathing in Las Vegas' (1998)
#   -> Coluna 'Gross' preenchida com revenue: 10700000
#
# Processando: 'Funny Games' (1997)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Dark City' (1998)
#   -> Coluna 'Gross' preenchida com revenue: 27200000
#
# Processando: 'Sleepers' (1996)
#   -> Coluna 'Gross' preenchida com revenue: 165600000
#
# Processando: 'Lost Highway' (1997)
#   -> Coluna 'Gross' preenchida com revenue: 3836866
#
# Processando: 'Sense and Sensibility' (1995)
#   -> Coluna 'Gross' preenchida com revenue: 134582776
#
# Processando: 'Die Hard: With a Vengeance' (1995)
#   -> Coluna 'Gross' preenchida com revenue: 366101666
#
# Processando: 'Dead Man' (1995)
#   -> Coluna 'Gross' preenchida com revenue: 1038000
#
# Processando: 'The Bridges of Madison County' (1995)
#   -> Coluna 'Gross' preenchida com revenue: 182000000
#
# Processando: 'Apollo 13' (1995)
#   -> Coluna 'Gross' preenchida com revenue: 355237933
#
# Processando: 'Trois couleurs: Blanc' (1994)
#   -> Coluna 'Gross' preenchida com revenue: 1273525
#
# Processando: 'Falling Down' (1993)
#   -> Coluna 'Gross' preenchida com revenue: 40903593
#
# Processando: 'Dazed and Confused' (1993)
#   -> Coluna 'Gross' preenchida com revenue: 8259076
#
# Processando: 'My Cousin Vinny' (1992)
#   -> Coluna 'Gross' preenchida com revenue: 64088552
#
# Processando: 'Omohide poro poro' (1991)
#   -> Coluna 'Gross' preenchida com revenue: 473110
#
# Processando: 'Delicatessen' (1991)
#   -> Coluna 'Gross' preenchida com revenue: 1794187
#
# Processando: 'Home Alone' (1990)
#   -> Coluna 'Gross' preenchida com revenue: 476684675
#
# Processando: 'The Godfather: Part III' (1990)
#   -> Coluna 'Gross' preenchida com revenue: 136766062
#
# Processando: 'When Harry Met Sally...' (1989)
#   -> Coluna 'Gross' preenchida com revenue: 92823546
#
# Processando: 'The Little Mermaid' (1989)
#   -> Coluna 'Gross' preenchida com revenue: 211343479
#
# Processando: 'The Naked Gun: From the Files of Police Squad!' (1988)
#   -> Coluna 'Gross' preenchida com revenue: 152356177
#
# Processando: 'Planes, Trains & Automobiles' (1987)
#   -> Coluna 'Gross' preenchida com revenue: 49500000
#
# Processando: 'Lethal Weapon' (1987)
#   -> Coluna 'Gross' preenchida com revenue: 120207127
#
# Processando: 'Blood Simple' (1984)
#   -> Coluna 'Gross' preenchida com revenue: 4229114
#
# Processando: 'On Golden Pond' (1981)
#   -> Coluna 'Gross' preenchida com revenue: 119285432
#
# Processando: 'Mad Max 2' (1981)
#   -> Coluna 'Gross' preenchida com revenue: 24600832
#
# Processando: 'The Warriors' (1979)
#   -> Coluna 'Gross' preenchida com revenue: 22490039
#
# Processando: 'The Muppet Movie' (1979)
#   -> Coluna 'Gross' preenchida com revenue: 75200000
#
# Processando: 'Escape from Alcatraz' (1979)
#   -> Coluna 'Gross' preenchida com revenue: 43004381
#
# Processando: 'Watership Down' (1978)
#   -> Coluna 'Gross' preenchida com revenue: 3713768
#
# Processando: 'Midnight Express' (1978)
#   -> Coluna 'Gross' preenchida com revenue: 35000000
#
# Processando: 'Close Encounters of the Third Kind' (1977)
#   -> Coluna 'Gross' preenchida com revenue: 306889114
#
# Processando: 'The Long Goodbye' (1973)
#   -> Coluna 'Gross' preenchida com revenue: 959000
#
# Processando: 'Giù la testa' (1971)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'Kelly's Heroes' (1970)
#   -> Coluna 'Gross' preenchida com revenue: 5200000
#
# Processando: 'The Jungle Book' (1967)
#   -> Coluna 'Gross' preenchida com revenue: 378000000
#
# Processando: 'Blowup' (1966)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processando: 'A Hard Day's Night' (1964)
#   -> Coluna 'Gross' preenchida com revenue: 11000000
#
# Processando: 'Breakfast at Tiffany's' (1961)
#   -> Coluna 'Gross' preenchida com revenue: 9500000
#
# Processando: 'Giant' (1956)
#   -> Coluna 'Gross' preenchida com revenue: 32855818
#
# Processando: 'From Here to Eternity' (1953)
#   -> Coluna 'Gross' preenchida com revenue: 30500000
#
# Processando: 'Lifeboat' (1944)
#   -> Coluna 'Gross' preenchida com revenue: 1000000
#
# Processando: 'The 39 Steps' (1935)
#   -> Coluna 'Gross' preenchida com revenue: 0
#
# Processo de enriquecimento de dados concluído.

# %%
if 'Gross' in df.columns:
    df.drop(columns=['Gross'], inplace=True)

# %%
financial_cols = ['Budget', 'Revenue']
for col in financial_cols:
    df[col] = df[col].replace(0, np.nan)

# %%
df.isnull().sum()
# Out:
# Budget                  155
# Certificate               0
# Keywords                  0
# Original_Language         6
# Popularity                6
# Production_Companies      6
# Production_Countries      6
# Released_Year             0
# Revenue                 117
# Series_Title              0
# date_details              0
# dtype: int64

# %% [markdown]
# Arrumando detalhes de formatação para df final

# %%
import ast

def safe_literal_eval(val):
    if isinstance(val, str):
        try:
            return ast.literal_eval(val)
        except (ValueError, SyntaxError):

            return val

    return val

cols_to_convert = ['Keywords', 'Production_Companies', 'Production_Countries']
for col in cols_to_convert:
    df[col] = df[col].apply(safe_literal_eval)
# Out:
# Columns successfully converted.

# %%
df.to_csv('../data/processed/check_4_processing.csv', index=False)

# %%
df = pd.read_csv('../data/processed/check_4_processing.csv')
pre_processed_df = pd.read_csv('../data/processed/pre_feature_eng.csv')
df.head()
# Out:
#         Budget Certificate                                           Keywords  \
# 0    6000000.0           R  ['based on novel or book', 'loss of loved one'...
# 1  185000000.0       PG-13  ['sadism', 'chaos', 'secret identity', 'crime ...
# 2   13000000.0           R  ["new year's eve", 'new york city', 'based on ...
# 3     397751.0          NR  ['death penalty', 'anonymity', 'court case', '...
# 4   94000000.0       PG-13  ['army', 'based on novel or book', 'elves', 'd...
#
#   Original_Language  Popularity  \
# 0                en     26.3622
# 1                en     29.9949
# 2                en     16.6569
# 3                en     12.3449
# 4                en     23.6182
#
#                                 Production_Companies  \
# 0       ['Paramount Pictures', 'Alfran Productions']
# 1  ['Warner Bros. Pictures', 'Legendary Pictures'...
# 2      ['Paramount Pictures', 'The Coppola Company']
# 3       ['United Artists', 'Orion-Nova Productions']
# 4  ['New Line Cinema', 'WingNut Films', 'The Saul...
#
#                              Production_Countries  Released_Year  \
# 0                    ['United States of America']           1972
# 1  ['United Kingdom', 'United States of America']           2008
# 2                    ['United States of America']           1974
# 3                    ['United States of America']           1957
# 4     ['New Zealand', 'United States of America']           2003
#
#         Revenue                                   Series_Title date_details
# 0  2.450664e+08                                  The Godfather   1972-03-14
# 1  1.004558e+09                                The Dark Knight   2008-07-14
# 2  1.026000e+08                         The Godfather: Part II   1974-12-12
# 3  4.360000e+06                                   12 Angry Men   1957-04-10
# 4  1.118889e+09  The Lord of the Rings: The Return of the King   2003-12-01

# %%
display(pre_processed_df['Certificate'].value_counts())
display(df['Certificate'].value_counts())

mask = (
    (pre_processed_df['Certificate'] == 'Unrated') |
    (pre_processed_df['Certificate'].isna()) |
    (pre_processed_df['Certificate'] == 'NR')
)

pre_processed_df.loc[mask, 'Certificate'] = df.loc[mask, 'Certificate'].values
# Out:
# Certificate
# U           234
# A           196
# UA          175
# R           146
# PG-13        43
# PG           37
# Passed       34
# G            12
# Approved     11
# TV-PG         3
# GP            2
# TV-14         1
# Unrated       1
# TV-MA         1
# 16            1
# U/A           1
# Name: count, dtype: int64
# Certificate
# R           379
# PG-13       178
# PG          165
# NR          144
# G            51
# 15           19
# U            15
# U/A          14
# 12            8
# NC-17         4
# TP            4
# 16            3
# R15+          3
# 18            3
# 6             2
# R18+          2
# Approved      2
# A             1
# 12A           1
# 14            1
# Name: count, dtype: int64

# %%
certificate_full_rank_map = {
    'Unrated': 0,
    'NR': 0,

    'G': 1,
    'U': 1,
    'Passed': 1,
    'Approved': 1,
    'TP': 1,

    'PG': 2,
    'GP': 2,       
    'TV-PG': 2,
    '6': 2,


    'PG-13': 3,
    'UA': 3,       
    'U/A': 3,
    'TV-14': 3,
    '12': 3,
    '12A': 3,
    '14': 3,

    'R': 4,
    '15': 4,
    '16': 4,
    'R15+': 4,


    'NC-17': 5,
    'A': 5,
    'TV-MA': 5,
    '18': 5,
    'R18+': 5
}

df['Certificate_ord'] = df['Certificate'].map(certificate_full_rank_map)
pre_processed_df['Certificate_ord'] = pre_processed_df['Certificate'].map(certificate_full_rank_map)

# %%
pre_processed_df['Certificate_ord'] = pre_processed_df['Certificate_ord'].fillna(df['Certificate_ord'])
pre_processed_df['Certificate'] = pre_processed_df['Certificate'].fillna(df['Certificate'])

# %%
display(df.columns)

display(pre_processed_df.columns)
# Out:
# Index(['Budget', 'Certificate', 'Keywords', 'Original_Language', 'Popularity',
#        'Production_Companies', 'Production_Countries', 'Released_Year',
#        'Revenue', 'Series_Title', 'date_details', 'Certificate_ord'],
#       dtype='object')
# Index(['Series_Title', 'Released_Year', 'Certificate', 'Runtime', 'Genre',
#        'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1', 'Star2',
#        'Star3', 'Star4', 'No_of_Votes', 'Gross', 'Certificate_ord'],
#       dtype='object')

# %%
pre_processed_df['Budget'] = df['Budget']
pre_processed_df['Revenue'] = df['Revenue']
pre_processed_df['Popularity'] = df['Popularity']
pre_processed_df['Original_Language'] = df['Original_Language']
pre_processed_df['Production_Companies'] = df['Production_Companies']
pre_processed_df['Production_Countries'] = df['Production_Countries']
pre_processed_df['Keywords'] = df['Keywords']
pre_processed_df['date_details'] = df['date_details']

# %%
fator = pre_processed_df['Gross'].mean() / pre_processed_df['Revenue'].mean()
pre_processed_df['Gross_fill'] = pre_processed_df['Gross'].fillna(pre_processed_df['Revenue'] * fator)
pre_processed_df['Gross_fill'] = pre_processed_df['Gross_fill'].fillna(pre_processed_df['Gross'].median())

print(fator)
# Out:
# 0.4423645977977842

# %%
factor_med = (pre_processed_df['Revenue'] / pre_processed_df['Budget']).median()
pre_processed_df['Budget'] = pre_processed_df['Budget'].fillna(pre_processed_df['Revenue'] / factor_med)
pre_processed_df['Revenue'] = pre_processed_df['Revenue'].fillna(pre_processed_df['Budget'] * factor_med)

# %%
pre_processed_df.isna().sum().sort_values(ascending=False)
# Out:
# Gross                   169
# Meta_score              157
# Budget                   85
# Revenue                  85
# Popularity                6
# Original_Language         6
# Production_Countries      6
# Production_Companies      6
# Series_Title              0
# Director                  0
# Overview                  0
# IMDB_Rating               0
# Genre                     0
# Certificate               0
# Runtime                   0
# Released_Year             0
# Star1                     0
# Certificate_ord           0
# No_of_Votes               0
# Star3                     0
# Star4                     0
# Star2                     0
# Keywords                  0
# date_details              0
# Gross_fill                0
# dtype: int64

# %%
pre_processed_df
# Out:
#                                       Series_Title  Released_Year Certificate  \
# 0                                    The Godfather           1972           A
# 1                                  The Dark Knight           2008          UA
# 2                           The Godfather: Part II           1974           A
# 3                                     12 Angry Men           1957           U
# 4    The Lord of the Rings: The Return of the King           2003           U
# ..                                             ...            ...         ...
# 994                         Breakfast at Tiffany's           1961           A
# 995                                          Giant           1956           G
# 996                          From Here to Eternity           1953      Passed
# 997                                       Lifeboat           1944          NR
# 998                                   The 39 Steps           1935          NR
#
#      Runtime                     Genre  IMDB_Rating  \
# 0        175              Crime, Drama          9.2
# 1        152      Action, Crime, Drama          9.0
# 2        202              Crime, Drama          9.0
# 3         96              Crime, Drama          9.0
# 4        201  Action, Adventure, Drama          8.9
# ..       ...                       ...          ...
# 994      115    Comedy, Drama, Romance          7.6
# 995      201            Drama, Western          7.6
# 996      118       Drama, Romance, War          7.6
# 997       97                Drama, War          7.6
# 998       86  Crime, Mystery, Thriller          7.6
#
#                                               Overview  Meta_score  \
# 0    An organized crime dynasty's aging patriarch t...       100.0
# 1    When the menace known as the Joker wreaks havo...        84.0
# 2    The early life and career of Vito Corleone in ...        90.0
# 3    A jury holdout attempts to prevent a miscarria...        96.0
# 4    Gandalf and Aragorn lead the World of Men agai...        94.0
# ..                                                 ...         ...
# 994  A young New York socialite becomes interested ...        76.0
# 995  Sprawling epic covering the life of a Texas ca...        84.0
# 996  In Hawaii in 1941, a private is cruelly punish...        85.0
# 997  Several survivors of a torpedoed merchant ship...        78.0
# 998  A man in London tries to help a counter-espion...        93.0
#
#                  Director              Star1  ... Certificate_ord  \
# 0    Francis Ford Coppola      Marlon Brando  ...               5
# 1       Christopher Nolan     Christian Bale  ...               3
# 2    Francis Ford Coppola          Al Pacino  ...               5
# 3            Sidney Lumet        Henry Fonda  ...               1
# 4           Peter Jackson        Elijah Wood  ...               1
# ..                    ...                ...  ...             ...
# 994         Blake Edwards     Audrey Hepburn  ...               5
# 995        George Stevens   Elizabeth Taylor  ...               1
# 996        Fred Zinnemann     Burt Lancaster  ...               1
# 997      Alfred Hitchcock  Tallulah Bankhead  ...               0
# 998      Alfred Hitchcock       Robert Donat  ...               0
#
#           Budget       Revenue  Popularity  Original_Language  \
# 0      6000000.0  2.450664e+08     26.3622                 en
# 1    185000000.0  1.004558e+09     29.9949                 en
# 2     13000000.0  1.026000e+08     16.6569                 en
# 3       397751.0  4.360000e+06     12.3449                 en
# 4     94000000.0  1.118889e+09     23.6182                 en
# ..           ...           ...         ...                ...
# 994    2500000.0  9.500000e+06      4.8948                 en
# 995    5400000.0  3.285582e+07      3.1848                 en
# 996    1650000.0  3.050000e+07      4.0353                 en
# 997    1590000.0  1.000000e+06      1.9989                 en
# 998          NaN           NaN      4.7672                 en
#
#                                   Production_Companies  \
# 0         ['Paramount Pictures', 'Alfran Productions']
# 1    ['Warner Bros. Pictures', 'Legendary Pictures'...
# 2        ['Paramount Pictures', 'The Coppola Company']
# 3         ['United Artists', 'Orion-Nova Productions']
# 4    ['New Line Cinema', 'WingNut Films', 'The Saul...
# ..                                                 ...
# 994           ['Paramount Pictures', 'Jurow-Shepherd']
# 995  ['Warner Bros. Pictures', 'George Stevens Jr. ...
# 996                              ['Columbia Pictures']
# 997                               ['20th Century Fox']
# 998            ['Gaumont-British Picture Corporation']
#
#                                Production_Countries  \
# 0                      ['United States of America']
# 1    ['United Kingdom', 'United States of America']
# 2                      ['United States of America']
# 3                      ['United States of America']
# 4       ['New Zealand', 'United States of America']
# ..                                              ...
# 994                    ['United States of America']
# 995                    ['United States of America']
# 996                    ['United States of America']
# 997                    ['United States of America']
# 998                              ['United Kingdom']
#
#                                               Keywords  date_details  \
# 0    ['based on novel or book', 'loss of loved one'...    1972-03-14
# 1    ['sadism', 'chaos', 'secret identity', 'crime ...    2008-07-14
# 2    ["new year's eve", 'new york city', 'based on ...    1974-12-12
# 3    ['death penalty', 'anonymity', 'court case', '...    1957-04-10
# 4    ['army', 'based on novel or book', 'elves', 'd...    2003-12-01
# ..                                                 ...           ...
# 994  ['new york city', "love of one's life", 'broke...    1961-10-05
# 995  ['hotel', 'petrol', 'jealousy', 'judge', 'fune...    1956-10-10
# 996  ['beach', 'based on novel or book', 'hawaii', ...    1953-08-05
# 997  ['sea', 'journalist', 'submarine', 'boat', 'wo...    1944-01-11
# 998  ['london, england', 'based on novel or book', ...    1935-06-06
#
#        Gross_fill
# 0    1.349664e+08
# 1    5.348584e+08
# 2    5.730000e+07
# 3    4.360000e+06
# 4    3.778459e+08
# ..            ...
# 994  4.202464e+06
# 995  1.453425e+07
# 996  3.050000e+07
# 997  4.423646e+05
# 998  2.345744e+07
#
# [999 rows x 25 columns]

# %%
certificate_mapping = {
    'U': 'G', 'Approved': 'G', 'Passed': 'G', 'TP': 'G',
    '6': 'PG',
    'UA': 'PG-13', 'U/A': 'PG-13', '12': 'PG-13', '12A': 'PG-13', '14': 'PG-13',
    '15': 'R', '16': 'R', 'R15+': 'R',
    'A': 'NC-17', '18': 'NC-17', 'R18+': 'NC-17',
    'NR': 'Unrated'
}
pre_processed_df['Certificate'] = pre_processed_df['Certificate'].map(certificate_mapping).fillna('Unrated')

# %%
df['Certificate'].value_counts()
# Out:
# Certificate
# R           379
# PG-13       178
# PG          165
# NR          144
# G            51
# 15           19
# U            15
# U/A          14
# 12            8
# NC-17         4
# TP            4
# 16            3
# R15+          3
# 18            3
# 6             2
# R18+          2
# Approved      2
# A             1
# 12A           1
# 14            1
# Name: count, dtype: int64

# %%
pre_processed_df['Certificate'].value_counts()
# Out:
# Certificate
# Unrated    322
# G          286
# NC-17      198
# PG-13      181
# R           12
# Name: count, dtype: int64

# %%
pre_processed_df.describe()
# Out:
#        Released_Year     Runtime  IMDB_Rating  Meta_score   No_of_Votes  \
# count     999.000000  999.000000   999.000000  842.000000  9.990000e+02
# mean     1991.218218  122.871872     7.947948   77.969121  2.716214e+05
# std        23.297166   28.101227     0.272290   12.383257  3.209126e+05
# min      1920.000000   45.000000     7.600000   28.000000  2.508800e+04
# 25%      1976.000000  103.000000     7.700000   70.000000  5.547150e+04
# 50%      1999.000000  119.000000     7.900000   79.000000  1.383560e+05
# 75%      2009.000000  137.000000     8.100000   87.000000  3.731675e+05
# max      2020.000000  321.000000     9.200000  100.000000  2.303232e+06
#
#               Gross  Certificate_ord        Budget       Revenue  Popularity  \
# count  8.300000e+02       999.000000  9.140000e+02  9.140000e+02  993.000000
# mean   6.808257e+07         2.740741  2.837943e+07  1.492503e+08    6.658564
# std    1.098076e+08         1.636217  4.838764e+07  2.838934e+08    5.725451
# min    1.305000e+03         0.000000  1.050000e+02  3.193000e+03    0.007900
# 25%    3.245338e+06         1.000000  2.555600e+06  9.031733e+06    2.779600
# 50%    2.345744e+07         3.000000  9.000000e+06  4.002362e+07    4.654800
# 75%    8.087634e+07         4.000000  2.875000e+07  1.500000e+08    8.925500
# max    9.366622e+08         5.000000  3.560000e+08  2.923706e+09   47.132600
#
#          Gross_fill
# count  9.990000e+02
# mean   5.897940e+07
# std    1.021981e+08
# min    1.305000e+03
# 25%    3.129808e+06
# 50%    2.245598e+07
# 75%    6.157656e+07
# max    9.366622e+08

# %%
pre_processed_df['Brute_Profit'] = pre_processed_df['Revenue'] - pre_processed_df['Budget']
pre_processed_df['ROI'] = pre_processed_df['Brute_Profit'] / pre_processed_df['Budget']

# %%
#timestamp 1970

pre_processed_df['Timestamp'] = pd.to_datetime(pre_processed_df['date_details'], errors='coerce')
pre_processed_df['Timestamp'] = pre_processed_df['Timestamp'].astype('int64') // 10**9
pre_processed_df['Timestamp'].value_counts()
# Out:
# Timestamp
#  1347062400    3
#  1157068800    3
#  1400198400    3
#  863568000     2
#  1453507200    2
#               ..
# -260064000     1
# -417398400     1
# -517795200     1
# -819676800     1
#  1215993600    1
# Name: count, Length: 948, dtype: int64

# %%
df

# %%
pre_processed_df.to_csv('../data/processed/final_df.csv', index=False)
